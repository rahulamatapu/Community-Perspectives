# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulamatapu/Community-Perspectives/blob/master/Unbiased_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install langchain langchain_experimental openai
# !pip install -U langchain-openai

from langchain_openai import ChatOpenAI
# set environment variables
# https://platform.openai.com/account/api-keys
import os
os.environ["OPENAI_API_KEY"] = ""


from langchain.prompts import FewShotPromptTemplate, PromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain.pydantic_v1 import BaseModel
from langchain_experimental.tabular_synthetic_data.base import SyntheticDataGenerator
from langchain_experimental.tabular_synthetic_data.openai import create_openai_data_generator, OPENAI_TEMPLATE
from langchain_experimental.tabular_synthetic_data.prompts import SYNTHETIC_FEW_SHOT_SUFFIX, SYNTHETIC_FEW_SHOT_PREFIX

# %%
import random
import itertools
from pydantic import BaseModel, Field
from pydantic import ConfigDict
from typing import Optional
from typing import List
from langchain_experimental.tabular_synthetic_data.openai import create_openai_data_generator
from langchain_core.prompts import FewShotPromptTemplate, PromptTemplate
from langchain_openai import ChatOpenAI

# %%
from typing import List, Dict, Tuple
from pydantic.v1 import BaseModel
# Scenario Information


# Persona Information
class PersonaInformation(BaseModel):
    persona_id: str
    community: str
    age: int
    occupation: str
    household_composition: str
    disaster_experience: str
    socioeconomic_status: str
    community_description: str


# Response Data
    class Config:
        arbitrary_types_allowed = True

class ResponseData(BaseModel):
    response_id: str
    scenario_id: str
    persona_id: str
    question_id: str
    option1: str
    option2: str
    priority_choice: str
    reasoning: str
    ordered_pair: List[str]

# Scenario Context
'''
class ScenarioContext(BaseModel):
    scenario_id: str
    description: str
    model_config = ConfigDict(arbitrary_types_allowed=True)
'''
# Community Context
class CommunityContext(BaseModel):
    community_id: str
    social_vulnerability_score: int
    access_to_resources: str
    population: int

# Question, we generate questions seperately below using a script
class Question(BaseModel):
    question_id: str
    option1: str
    option2: str
    text: str

# %%
community_contexts = {
    "Community 1": CommunityContext(
        community_id="C001",
        social_vulnerability_score=7,
        access_to_resources="Limited",
        population=5000
    ),
    "Community 2": CommunityContext(
        community_id="C002",
        social_vulnerability_score=4,
        access_to_resources="Moderate",
        population=12000
    ),
    "Community 3": CommunityContext(
        community_id="C003",
        social_vulnerability_score=2,
        access_to_resources="Good",
        population=20000
    )
}

infrastructure_status = {
    "Community 1": {
        "Power School": 1, "Water School": 0, "Power House": 1, "Water House": 1,
        "Power Residential": 0, "Water Residential": 0, "Power Commercial": 1, "Water Commercial": 1
    },
    "Community 2": {
        "Power School": 1, "Water School": 1, "Power House": 1, "Water House": 1,
        "Power Residential": 0, "Water Residential": 0, "Power Commercial": 1, "Water Commercial": 0
    },
    "Community 3": {
        "Power School": 1, "Water School": 0, "Power House": 1, "Water House": 1,
        "Power Residential": 0, "Water Residential": 0, "Power Commercial": 1, "Water Commercial": 1
    }
}

# %%
def generate_community_description(community, status, context):
    working = [k for k, v in status.items() if v == 1]
    damaged = [k for k, v in status.items() if v == 0]
    return f"In {community}: " \
           f"- Working infrastructure: {', '.join(working)}; " \
           f"- Damaged infrastructure: {', '.join(damaged)}; " \
           f"- Population: {context.population}; " \
           f"- Social vulnerability score: {context.social_vulnerability_score}/10; " \
           f"- Access to resources: {context.access_to_resources}."


def generate_all_possible_questions():
    all_damaged = []
    for community, status in infrastructure_status.items():
        damaged = [(community, infra) for infra, working in status.items() if working == 0]
        all_damaged.extend(damaged)

    all_combinations = list(itertools.combinations(all_damaged, 2))

    questions = []
    for i, pair in enumerate(all_combinations, 1):
        question = Question(
            question_id=f"Q{i:03d}",
            option1=f"Repair {pair[0][1]} in {pair[0][0]}",
            option2=f"Repair {pair[1][1]} in {pair[1][0]}",
            text=f"Which should be repaired first: {pair[0][1]} in {pair[0][0]} or {pair[1][1]} in {pair[1][0]}?"
        )
        questions.append(question)

    return questions

def validate_response(response: ResponseData, persona: PersonaInformation, question: Question) -> Tuple[bool, str]:
    if response.priority_choice not in [question.option1, question.option2]:
        return False, f"Invalid priority choice: {response.priority_choice}"

    if set(response.ordered_pair) != set([question.option1, question.option2]):
        return False, f"Invalid ordered pair: {response.ordered_pair}"

    if len(response.reasoning) < 50:  # Ensure a minimum length for the reasoning
        return False, "Reasoning is too short"

    # Check if the reasoning mentions at least one community
    if not any(community in response.reasoning for community in ["Community 1", "Community 2", "Community 3"]):
        return False, "Reasoning does not mention any community"

    #if persona.occupation.lower() not in response.reasoning.lower():
        #return False, f"Reasoning does not mention the persona's occupation ({persona.occupation})"

    # Check if the reasoning mentions at least one infrastructure type
    #infrastructure_types = ["Water", "Power", "School", "Residential", "Commercial"]
    #if not any(infra_type in response.reasoning for infra_type in infrastructure_types):
        #return False, "Reasoning does not mention any infrastructure type"

    return True, "Valid response"

# %%
OPENAI_TEMPLATE = PromptTemplate(input_variables=["example"], template="{example}")

persona_examples = [
    {
        "example": """Persona ID: P001, Community: Community 1, Age: 35, Occupation: Teacher,
        Household Composition: Married with children, Disaster Experience: Experienced a flood 5 years ago,
        Socioeconomic Status: Middle class, Community Description: Population 5000, Social vulnerability score 7/10,
        Limited access to resources"""
    },
    {
        "example": """Persona ID: P002, Community: Community 2, Age: 52, Occupation: Nurse,
        Household Composition: Single, Disaster Experience: No major disaster experience,
        Socioeconomic Status: Middle class, Community Description: Population 12000, Social vulnerability score 4/10,
        Moderate access to resources"""
    },
    {
        "example": """Persona ID: P003, Community: Community 3, Age: 68, Occupation: Retired,
        Household Composition: Married, Disaster Experience: Survived a hurricane last year,
        Socioeconomic Status: Upper middle class, Community Description: Population 20000, Social vulnerability score 2/10,
        Good access to resources"""
    },
]

response_examples = [
    {
        "example": """Response ID: R001, Scenario ID: S001, Persona ID: P001, Question ID: Q001,
        Option 1: Repair Water School in Community 1, Option 2: Repair Power Residential in Community 2,
        Priority Choice: Repair Water School in Community 1,
        Reasoning: As a teacher in Community 1, I believe access to clean water in schools is crucial for maintaining hygiene and preventing the spread of diseases, especially after a disaster. Our community has limited resources and a high social vulnerability score, so ensuring our schools are operational is a top priority for education continuity and community resilience.
        Ordered Pair: ["Repair Water School in Community 1", "Repair Power Residential in Community 2"]"""
    },
    {
        "example": """Response ID: R002, Scenario ID: S001, Persona ID: P002, Question ID: Q002,
        Option 1: Repair Power Residential in Community 2, Option 2: Repair Water Residential in Community 3,
        Priority Choice: Repair Power Residential in Community 2,
        Reasoning: As a nurse in Community 2, I understand the critical importance of electrical power for medical equipment and maintaining communication during emergencies. Our community has moderate access to resources, and restoring power to residential areas will help more people in our larger population of 12,000 to manage their health needs at home, potentially reducing strain on medical facilities.
        Ordered Pair: ["Repair Power Residential in Community 2", "Repair Water Residential in Community 3"]"""
    },
    {
        "example": """Response ID: R003, Scenario ID: S001, Persona ID: P003, Question ID: Q003,
        Option 1: Repair Water Residential in Community 1, Option 2: Repair Power School in Community 3,
        Priority Choice: Repair Water Residential in Community 1,
        Reasoning: As a retired person living in Community 3, I recognize the dire need for water in residential areas of Community 1. Although I'm from a community with good access to resources, I believe we should prioritize the basic needs of the most vulnerable. Community 1 has a higher social vulnerability score and limited access to resources, making clean water for their homes a critical priority for health and sanitation.
        Ordered Pair: ["Repair Water Residential in Community 1", "Repair Power School in Community 3"]"""
    },
    {
        "example": """Response ID: R004, Scenario ID: S001, Persona ID: P004, Question ID: Q004,
        Option 1: Repair Power Commercial in Community 2, Option 2: Repair Water School in Community 3,
        Priority Choice: Repair Power Commercial in Community 2,
        Reasoning: As a small business owner in Community 2, I believe restoring power to commercial areas is crucial for economic recovery after a disaster. Our community has a moderate population of 12,000 and restoring commercial power will help businesses reopen, provide essential services, and support the local economy. This can indirectly benefit the entire region by maintaining supply chains and employment.
        Ordered Pair: ["Repair Power Commercial in Community 2", "Repair Water School in Community 3"]"""
    },
    {
        "example": """Response ID: R005, Scenario ID: S001, Persona ID: P005, Question ID: Q005,
        Option 1: Repair Water Commercial in Community 1, Option 2: Repair Power Residential in Community 3,
        Priority Choice: Repair Water Commercial in Community 1,
        Reasoning: As a public health official in Community 1, I prioritize repairing the water supply to commercial areas in our community. Given our high social vulnerability score of 7/10 and limited access to resources, restoring water to commercial areas will allow essential businesses like pharmacies and food stores to operate, supporting the basic needs of our 5,000 residents. This is critical for preventing secondary health crises in our vulnerable population.
        Ordered Pair: ["Repair Water Commercial in Community 1", "Repair Power Residential in Community 3"]"""
    }
]

# Create prompt templates
OPENAI_TEMPLATE = PromptTemplate(input_variables=["example"], template="{example}")

persona_prompt_template = FewShotPromptTemplate(
    prefix=SYNTHETIC_FEW_SHOT_PREFIX + """
    Generate diverse personas for a disaster scenario study. Ensure variety in:
    - Age: Include a range from teenagers to elderly (16-80+)
    - Occupations: Vary widely, including unemployed and students
    - Household compositions: Include single parents, multigenerational households, etc.
    - Disaster experiences: Some with no experience, others with various past experiences
    - Socioeconomic statuses: Ensure representation across all economic levels
    - Physical abilities: Include some personas with disabilities
    - Cultural backgrounds: Represent diverse ethnicities and cultural practices
    - Length of residency in the community: Mix of newcomers and long-time residents
    - Special circumstances: e.g., caretakers, pregnant, etc.

    Each persona should be unique and realistic.
    """,
    examples=persona_examples,
    suffix=SYNTHETIC_FEW_SHOT_SUFFIX,
    input_variables=["subject", "extra"],
    example_prompt=OPENAI_TEMPLATE,
)

response_prompt_template = FewShotPromptTemplate(
    prefix=SYNTHETIC_FEW_SHOT_PREFIX,
    examples=response_examples,
    suffix=SYNTHETIC_FEW_SHOT_SUFFIX + "\n\nPersona: {persona}\nQuestion: {question}\nGenerate a response:",
    input_variables=["subject", "extra", "persona", "question"],
    example_prompt=OPENAI_TEMPLATE,
)

# Create generators
persona_generator = create_openai_data_generator(
    output_schema=PersonaInformation,
    llm=ChatOpenAI(temperature=0.9),
    prompt=persona_prompt_template,
)

response_generator = create_openai_data_generator(
    output_schema=ResponseData,
    llm=ChatOpenAI(temperature=0.7),
    prompt=response_prompt_template,
)

# %%
import random

def generate_personas(num_personas: int) -> List[PersonaInformation]:
    communities = list(community_contexts.keys())

    # Generate descriptions for all communities
    community_descriptions = {
        community: generate_community_description(community, infrastructure_status[community], community_contexts[community])
        for community in communities
    }

    # Combine all community descriptions
    all_community_desc = " ".join(community_descriptions.values())

    occupations = {
        "Healthcare Worker": 2, "Teacher": 2, "First Responder": 2,
        "Local Government Employee": 2, "Small Business Owner": 2,
        "Factory Worker": 2, "Farmer": 2, "Retired": 2,
        "Unemployed": 2, "Student": 2, "Software Developer": 2,"Lawyer": 2, "Nurse":2,
        "Construction Worker": 2, "Social Worker": 2, "Accountant": 2
    }

    household_compositions = [
        "Single", "Married without children", "Married with young children",
        "Single parent", "Empty nester", "Multigenerational household",
        "Cohabiting partners", "Living with roommates"
    ]

    disaster_experiences = [
        "No major disaster experience",
        "Survived a flood 3 years ago",
        "Experienced a severe hurricane last year",
        "Lived through an earthquake 5 years ago",
        "Dealt with a major wildfire 2 years ago",
        "Multiple experiences with various natural disasters",
        "Volunteered in disaster relief efforts",
        "Lost home in a tornado 4 years ago"
    ]

    socioeconomic_statuses = ["Lower class", "Lower middle class", "Middle class", "Upper middle class", "Upper class"]

    additional_traits = [
        "Recent immigrant", "Long-time community leader", "Person with a physical disability",
        "Caregiver for elderly parent", "LGBTQ+ community member", "Veteran",
        "Climate change activist", "Technology enthusiast", "Local sports coach"
    ]

    weighted_occupations = [occupation for occupation, weight in occupations.items() for _ in range(weight)]

    extra_prompt = f"""Create {num_personas} unique personas with diverse characteristics including:
    - Ages ranging from 18 to 85+
    - Occupations from this list (some may appear more often): {', '.join(occupations.keys())}
    - Household compositions from this list: {', '.join(household_compositions)}
    - Disaster experiences from this list: {', '.join(disaster_experiences)}
    - Socioeconomic statuses from this list: {', '.join(socioeconomic_statuses)}
    - Additional traits (include one for each persona) from this list: {', '.join(additional_traits)}
    Ensure a diverse mix of characteristics across all personas, with a focus on how these characteristics might influence disaster preparedness and response.
    Community descriptions: {all_community_desc}"""

    synthetic_personas = persona_generator.generate(
        subject="storm_scenario_persona",
        extra=extra_prompt,
        runs=num_personas
    )[:num_personas]

    print(f"Generated {len(synthetic_personas)} personas.")

    # Ensure equal distribution of personas across communities
    personas_per_community = num_personas // len(communities)
    extra_personas = num_personas % len(communities)
    community_assignment = communities * personas_per_community + random.sample(communities, extra_personas)
    random.shuffle(community_assignment)

    for i, persona in enumerate(synthetic_personas):
        persona.persona_id = f"P{i+1:03d}"
        persona.community = community_assignment[i]
        persona.community_description = all_community_desc

        if "Additional trait:" not in persona.community_description:
            trait = random.choice(additional_traits)
            persona.community_description += f" Additional trait: {trait}."

        if not hasattr(persona, 'occupation') or not persona.occupation:
            persona.occupation = random.choice(weighted_occupations)

    return synthetic_personas

# Generate personas
num_personas_to_generate = 10
synthetic_personas = generate_personas(num_personas_to_generate)

# Print generated personas
for persona in synthetic_personas:
    print(persona.json(indent=2))
# Out:
# Generated 10 personas.
# {
#   "persona_id": "P001",
#   "community": "Community 2",
#   "age": 25,
#   "occupation": "Local Government Employee",
#   "household_composition": "Cohabiting partners",
#   "disaster_experience": "Volunteered in disaster relief efforts",
#   "socioeconomic_status": "Lower middle class",
#   "community_description": "In Community 1: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 5000; - Social vulnerability score: 7/10; - Access to resources: Limited. In Community 2: - Working infrastructure: Power School, Water School, Power House, Water House, Power Commercial; - Damaged infrastructure: Power Residential, Water Residential, Water Commercial; - Population: 12000; - Social vulnerability score: 4/10; - Access to resources: Moderate. In Community 3: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 20000; - Social vulnerability score: 2/10; - Access to resources: Good. Additional trait: LGBTQ+ community member."
# }
# {
#   "persona_id": "P002",
#   "community": "Community 3",
#   "age": 32,
#   "occupation": "Teacher",
#   "household_composition": "Single",
#   "disaster_experience": "Survived a flood 3 years ago",
#   "socioeconomic_status": "Middle class",
#   "community_description": "In Community 1: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 5000; - Social vulnerability score: 7/10; - Access to resources: Limited. In Community 2: - Working infrastructure: Power School, Water School, Power House, Water House, Power Commercial; - Damaged infrastructure: Power Residential, Water Residential, Water Commercial; - Population: 12000; - Social vulnerability score: 4/10; - Access to resources: Moderate. In Community 3: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 20000; - Social vulnerability score: 2/10; - Access to resources: Good. Additional trait: Climate change activist."
# }
# {
#   "persona_id": "P003",
#   "community": "Community 1",
#   "age": 23,
#   "occupation": "Social Worker",
#   "household_composition": "Single",
#   "disaster_experience": "Multiple experiences with various natural disasters",
#   "socioeconomic_status": "Middle class",
#   "community_description": "In Community 1: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 5000; - Social vulnerability score: 7/10; - Access to resources: Limited. In Community 2: - Working infrastructure: Power School, Water School, Power House, Water House, Power Commercial; - Damaged infrastructure: Power Residential, Water Residential, Water Commercial; - Population: 12000; - Social vulnerability score: 4/10; - Access to resources: Moderate. In Community 3: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 20000; - Social vulnerability score: 2/10; - Access to resources: Good. Additional trait: Local sports coach."
# }
# {
#   "persona_id": "P004",
#   "community": "Community 2",
#   "age": 28,
#   "occupation": "Healthcare Worker",
#   "household_composition": "Single parent",
#   "disaster_experience": "Dealt with a major wildfire 2 years ago",
#   "socioeconomic_status": "Middle class",
#   "community_description": "In Community 1: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 5000; - Social vulnerability score: 7/10; - Access to resources: Limited. In Community 2: - Working infrastructure: Power School, Water School, Power House, Water House, Power Commercial; - Damaged infrastructure: Power Residential, Water Residential, Water Commercial; - Population: 12000; - Social vulnerability score: 4/10; - Access to resources: Moderate. In Community 3: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 20000; - Social vulnerability score: 2/10; - Access to resources: Good. Additional trait: Recent immigrant."
# }
# {
#   "persona_id": "P005",
#   "community": "Community 2",
#   "age": 35,
#   "occupation": "Healthcare Worker",
#   "household_composition": "Married without children",
#   "disaster_experience": "Lived through an earthquake 5 years ago",
#   "socioeconomic_status": "Middle class",
#   "community_description": "In Community 1: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 5000; - Social vulnerability score: 7/10; - Access to resources: Limited. In Community 2: - Working infrastructure: Power School, Water School, Power House, Water House, Power Commercial; - Damaged infrastructure: Power Residential, Water Residential, Water Commercial; - Population: 12000; - Social vulnerability score: 4/10; - Access to resources: Moderate. In Community 3: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 20000; - Social vulnerability score: 2/10; - Access to resources: Good. Additional trait: Technology enthusiast."
# }
# {
#   "persona_id": "P006",
#   "community": "Community 1",
#   "age": 28,
#   "occupation": "First Responder",
#   "household_composition": "Multigenerational household",
#   "disaster_experience": "Survived a flood 3 years ago",
#   "socioeconomic_status": "Upper middle class",
#   "community_description": "In Community 1: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 5000; - Social vulnerability score: 7/10; - Access to resources: Limited. In Community 2: - Working infrastructure: Power School, Water School, Power House, Water House, Power Commercial; - Damaged infrastructure: Power Residential, Water Residential, Water Commercial; - Population: 12000; - Social vulnerability score: 4/10; - Access to resources: Moderate. In Community 3: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 20000; - Social vulnerability score: 2/10; - Access to resources: Good. Additional trait: Recent immigrant."
# }
# {
#   "persona_id": "P007",
#   "community": "Community 3",
#   "age": 28,
#   "occupation": "Healthcare Worker",
#   "household_composition": "Single parent",
#   "disaster_experience": "Dealt with a major wildfire 2 years ago",
#   "socioeconomic_status": "Middle class",
#   "community_description": "In Community 1: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 5000; - Social vulnerability score: 7/10; - Access to resources: Limited. In Community 2: - Working infrastructure: Power School, Water School, Power House, Water House, Power Commercial; - Damaged infrastructure: Power Residential, Water Residential, Water Commercial; - Population: 12000; - Social vulnerability score: 4/10; - Access to resources: Moderate. In Community 3: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 20000; - Social vulnerability score: 2/10; - Access to resources: Good. Additional trait: Recent immigrant."
# }
# {
#   "persona_id": "P008",
#   "community": "Community 3",
#   "age": 25,
#   "occupation": "Healthcare Worker",
#   "household_composition": "Single",
#   "disaster_experience": "No major disaster experience",
#   "socioeconomic_status": "Middle class",
#   "community_description": "In Community 1: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 5000; - Social vulnerability score: 7/10; - Access to resources: Limited. In Community 2: - Working infrastructure: Power School, Water School, Power House, Water House, Power Commercial; - Damaged infrastructure: Power Residential, Water Residential, Water Commercial; - Population: 12000; - Social vulnerability score: 4/10; - Access to resources: Moderate. In Community 3: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 20000; - Social vulnerability score: 2/10; - Access to resources: Good. Additional trait: Person with a physical disability."
# }
# {
#   "persona_id": "P009",
#   "community": "Community 2",
#   "age": 35,
#   "occupation": "Healthcare Worker",
#   "household_composition": "Married with young children",
#   "disaster_experience": "Survived a flood 3 years ago",
#   "socioeconomic_status": "Middle class",
#   "community_description": "In Community 1: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 5000; - Social vulnerability score: 7/10; - Access to resources: Limited. In Community 2: - Working infrastructure: Power School, Water School, Power House, Water House, Power Commercial; - Damaged infrastructure: Power Residential, Water Residential, Water Commercial; - Population: 12000; - Social vulnerability score: 4/10; - Access to resources: Moderate. In Community 3: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 20000; - Social vulnerability score: 2/10; - Access to resources: Good. Additional trait: Long-time community leader."
# }
# {
#   "persona_id": "P010",
#   "community": "Community 1",
#   "age": 28,
#   "occupation": "Healthcare Worker",
#   "household_composition": "Single parent",
#   "disaster_experience": "Dealt with a major wildfire 2 years ago",
#   "socioeconomic_status": "Middle class",
#   "community_description": "In Community 1: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 5000; - Social vulnerability score: 7/10; - Access to resources: Limited. In Community 2: - Working infrastructure: Power School, Water School, Power House, Water House, Power Commercial; - Damaged infrastructure: Power Residential, Water Residential, Water Commercial; - Population: 12000; - Social vulnerability score: 4/10; - Access to resources: Moderate. In Community 3: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 20000; - Social vulnerability score: 2/10; - Access to resources: Good. Additional trait: LGBTQ+ community member."
# }

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.schema import HumanMessage
import random
from typing import List, Optional
import pandas as pd

# Initialize the language model
llm = ChatOpenAI(temperature=0.7)

RESPONSES_PER_PERSONA = 10

def generate_responses_for_personas(
    personas: List[PersonaInformation],
    questions: List[Question],
    responses_per_persona: int = RESPONSES_PER_PERSONA,
    max_attempts: int = 5
) -> List[dict]:
    responses = []
    response_counter = 1

    for persona in personas:
        print(f"Generating responses for Persona ID: {persona.persona_id}, Occupation: {persona.occupation}")
        selected_questions = random.sample(questions, min(responses_per_persona, len(questions)))

        for question in selected_questions:
            print(f"\nProcessing question: {question.text}")
            valid_response = None
            attempts = 0

            while valid_response is None and attempts < max_attempts:
                try:
                    prompt = PromptTemplate(
                        input_variables=["persona", "occupation", "question", "option1", "option2", "all_community_descriptions"],
                        template="""You are a {persona}. Please answer the following question: '{question}'
                        You must choose between '{option1}' and '{option2}'.
                        Provide a detailed reasoning specific to these options and your background.
                        Your response MUST include both a priority choice and a reasoning.

                        Information about all communities:
                        {all_community_descriptions}

                        Respond in the following format:
                        Priority Choice: [Your chosen option]
                        Reasoning: [Your detailed reasoning]"""
                    )

                    formatted_prompt = prompt.format(
                        persona=f"{persona.occupation}",  # Removed specific community
                        occupation=persona.occupation,
                        question=question.text,
                        option1=question.option1,
                        option2=question.option2,
                        all_community_descriptions=persona.community_description
                    )

                    response = llm.invoke([HumanMessage(content=formatted_prompt)])

                    # Parse the response
                    response_text = response.content
                    print(f"Response: {response_text}")
                    lines = response_text.split('\n')
                    priority_choice = next((line.split(': ', 1)[1].strip() for line in lines if line.startswith("Priority Choice:")), None)
                    reasoning = next((line.split(': ', 1)[1].strip() for line in lines if line.startswith("Reasoning:")), None)

                    if priority_choice not in [question.option1, question.option2]:
                        print(f"Invalid priority choice: {priority_choice}. Retrying.")
                        attempts += 1
                        continue

                    if not reasoning:
                        print("No reasoning provided. Retrying.")
                        attempts += 1
                        continue

                    ordered_pair = [
                        priority_choice,
                        question.option2 if priority_choice == question.option1 else question.option1
                    ]

                    response_data = ResponseData(
                        response_id=f"R{response_counter:03d}",
                        scenario_id="S001",
                        persona_id=persona.persona_id,
                        question_id=question.question_id,
                        option1=question.option1,
                        option2=question.option2,
                        priority_choice=priority_choice,
                        reasoning=reasoning,
                        ordered_pair=ordered_pair
                    )

                    validation_result, validation_message = validate_response(response_data, persona, question)
                    if validation_result:
                        valid_response = {
                            **response_data.dict(),
                            'community': persona.community,
                            'age': persona.age,
                            'occupation': persona.occupation,
                            'household_composition': persona.household_composition,
                            'disaster_experience': persona.disaster_experience,
                            'socioeconomic_status': persona.socioeconomic_status,
                            'community_description': persona.community_description
                        }
                        responses.append(valid_response)
                        response_counter += 1
                        print("Valid response generated.")
                    else:
                        print(f"Response validation failed: {validation_message}. Retrying...")

                except Exception as e:
                    print(f"Error generating response: {str(e)}")

                attempts += 1

            if valid_response is None:
                print(f"Failed to generate valid response after {max_attempts} attempts")

    return responses

# Generate personas
num_personas_to_generate = 200
print("\n--- Generating Personas ---")
synthetic_personas = generate_personas(num_personas_to_generate)

print("\n--- Summary of Generated Personas ---")
for persona in synthetic_personas:
    print(f"Persona ID: {persona.persona_id}, Occupation: {persona.occupation}, Community: {persona.community}")

# Generate questions
questions = generate_all_possible_questions()

# Generate responses
responses = generate_responses_for_personas(synthetic_personas, questions)

# Create DataFrame for responses (which now include persona information)
responses_df = pd.DataFrame(responses)

# Save to a single CSV file
responses_df.to_csv('personas_and_responses.csv', index=False)
print("\nPersona and Response information has been written to personas_and_responses.csv")

# Print results
print(f"\nGenerated {len(responses)} total responses.")
print(responses_df[['response_id', 'persona_id', 'community', 'occupation', 'priority_choice']])
# Out:
# Streaming output truncated to the last 5000 lines.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 2 or Power Residential in Community 3?
# Response: Priority Choice: Repair Power Residential in Community 2
#
# Reasoning: As a Medical Doctor, my primary concern is the health and well-being of the residents in these communities. Community 2 has a larger population of 12000 compared to Community 3's population of 20000. The damaged infrastructure in Community 2 includes Power Residential, Water Residential, and Water Commercial. By repairing the Power Residential in Community 2, we can ensure that a significant portion of the population has access to essential services such as electricity for medical equipment, heating, and cooling. This will directly impact the health and safety of a larger number of people in need. Additionally, the social vulnerability score of Community 2 is higher at 4/10 compared to Community 3's score of 2/10, indicating a greater need for support and resources in Community 2. Considering these factors, prioritizing the repair of Power Residential in Community 2 will have a more significant positive impact on the overall well-being of the community.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 2 or Water Residential in Community 3?
# Response: Priority Choice: Repair Power Residential in Community 2
#
# Reasoning: As a Medical Doctor, my primary concern is the health and well-being of the residents in these communities. In this scenario, repairing the Power Residential infrastructure in Community 2 should be the priority. Community 2 has a larger population of 12,000 people compared to Community 3 with 20,000 people. The social vulnerability score in Community 2 is also relatively higher at 4/10 compared to Community 3 with a score of 2/10.
#
# Additionally, access to resources in Community 2 is moderate, which means that the residents may face more challenges in dealing with the consequences of a power outage in their residential areas. Power is essential for various medical equipment, refrigeration of medications, and maintaining a comfortable living environment, especially for vulnerable populations such as the elderly and individuals with chronic illnesses.
#
# While access to resources in Community 3 is good, the lower population and social vulnerability score suggest that the impact of a water outage in the residential areas may be less severe compared to a power outage in Community 2. Furthermore, being a technology enthusiast community, the residents in Community 3 may have alternative ways to access water or cope with a temporary water shortage.
#
# Therefore, repairing the Power Residential infrastructure in Community 2 would have a greater impact on the health and well-being of a larger population with higher social vulnerability and limited access to resources.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Water Commercial in Community 2?
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Medical Doctor, I understand the importance of access to clean water for the health and well-being of a community. In Community 1, the Water School is the only damaged infrastructure related to water, while in Community 2, the Water Commercial is the only damaged water infrastructure. However, considering the population size and social vulnerability score of each community, repairing the Water School in Community 1 takes precedence.
#
# Community 1 has a smaller population of 5000 people and a higher social vulnerability score of 7/10, indicating that the residents may face challenges in accessing resources and healthcare services. By repairing the Water School in Community 1, not only are we ensuring that the residents have access to clean water for drinking and sanitation purposes, but we are also prioritizing the health and safety of the children who attend the school.
#
# On the other hand, Community 2 has a larger population of 12000 people and a lower social vulnerability score of 4/10. While access to clean water is crucial for all communities, the immediate impact on a smaller and more vulnerable population in Community 1 makes repairing the Water School there a more pressing priority. Additionally, the access to resources in Community 2 is described as moderate, suggesting that they may have more options for obtaining clean water compared to Community 1.
#
# In conclusion, repairing the Water School in Community 1 will address the critical need for clean water in a vulnerable population, aligning with the healthcare principles of prevention and community well-being.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Residential in Community 1 or Power Residential in Community 3?
# Response: Priority Choice: Repair Water Residential in Community 1
# Reasoning: As a Medical Doctor, my primary concern is the health and well-being of the residents in these communities. In Community 1, the water residential infrastructure is damaged, which can lead to a lack of access to clean and safe water for the residents. This can result in a variety of health issues such as waterborne diseases, dehydration, and poor sanitation practices. With a social vulnerability score of 7/10 and limited access to resources, it is crucial to prioritize repairing the water infrastructure in Community 1 to ensure the residents have access to clean water for drinking, cooking, and sanitation purposes. Additionally, by addressing this issue first, we can prevent potential health crises and improve the overall quality of life for the population in Community 1.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 3 or Water Residential in Community 3?
# Response: Priority Choice: Repair Water Residential in Community 3
#
# Reasoning: Given that Community 3 has a larger population compared to Community 1 and Community 2, it is essential to prioritize the repair of Water Residential infrastructure in Community 3. Water is a basic necessity for daily living, hygiene, and sanitation, especially in residential areas where a large number of people reside. By ensuring the availability of clean and safe water in residential areas, we can prevent the spread of waterborne diseases and improve the overall health and well-being of the community members.
#
# Furthermore, considering that Community 3 has a good access to resources and a lower social vulnerability score, it is likely that the repair of Water Residential infrastructure in this community can be carried out more efficiently and effectively. This will not only benefit the residents in terms of their health and quality of life but also contribute to the overall development and sustainability of the community.
#
# As a Medical Doctor, I understand the importance of access to clean water for the health of individuals and communities. Therefore, prioritizing the repair of Water Residential infrastructure in Community 3 aligns with my background and expertise in promoting public health and well-being.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Residential in Community 1 or Water School in Community 3?
# Response: Priority Choice: Repair Water School in Community 3
#
# Reasoning: As a Medical Doctor, my priority is to ensure the health and well-being of the largest number of people possible. Community 3 has the highest population of 20,000 and a lower social vulnerability score of 2/10 compared to Community 1 and Community 2. Additionally, Community 3 has good access to resources, which can facilitate the repair process. By prioritizing the repair of the Water School in Community 3, we can ensure that a large number of children have access to clean and safe water, which is essential for their overall health and education. This decision aligns with my background in healthcare and my commitment to improving community health outcomes.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Power Residential in Community 3?
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Medical Doctor, my primary concern is the health and well-being of the community members. In Community 1, the Water School is the only damaged infrastructure related to education and community development. Access to clean water is essential for maintaining good health, preventing diseases, and ensuring proper sanitation in schools. By prioritizing the repair of the Water School in Community 1, we can provide a safe and healthy learning environment for the children, ultimately leading to better overall health outcomes for the community. Additionally, addressing the water needs of the school can have a ripple effect on the entire community by improving access to clean water sources for all residents. While repairing the Power Residential in Community 3 is important for daily living, the immediate health benefits and community impact of repairing the Water School in Community 1 make it the top priority.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Residential in Community 1 or Water Residential in Community 2?
# Response: Priority Choice: Repair Water Residential in Community 2
#
# Reasoning: Given the information provided, Community 2 has a larger population of 12000 compared to Community 1 with a population of 5000. Additionally, Community 2 has a lower social vulnerability score of 4/10 compared to Community 1 with a score of 7/10. This indicates that Community 2 may be more at risk if the water residential infrastructure is not repaired promptly. Moreover, Community 2 has moderate access to resources, which suggests that they may have the means to address other pressing needs if the water residential issue is resolved first. Repairing the water residential infrastructure in Community 2 will not only benefit a larger population but also help mitigate potential health risks associated with inadequate access to clean water.
# Valid response generated.
# Generating responses for Persona ID: P143, Occupation: Local Government Employee
#
# Processing question: Which should be repaired first: Power Residential in Community 1 or Water Residential in Community 3?
# Response: Priority Choice: Repair Water Residential in Community 3
#
# Reasoning: As a Local Government Employee with a background in managing infrastructure projects, I believe that repairing the Water Residential in Community 3 should take priority over repairing the Power Residential in Community 1. Community 3 has a larger population of 20,000 residents compared to Community 1's 5,000 residents. Additionally, Community 3 has a lower social vulnerability score of 2/10 and better access to resources, indicating that the residents in this community may be more equipped to handle temporary disruptions in power supply compared to water supply.
#
# Furthermore, water is an essential resource for daily living and health, and the lack of access to clean water can have severe consequences for the residents of Community 3. By prioritizing the repair of the Water Residential infrastructure in Community 3, we can ensure that the basic needs of a larger population are met and prevent potential health and sanitation issues.
#
# Although I am a technology enthusiast, the primary consideration should be the immediate well-being and safety of the residents, which is why I believe repairing the Water Residential infrastructure in Community 3 should be the top priority. Once the water supply is restored, we can then focus on addressing the power issues in Community 1.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 1 or Water Commercial in Community 2?
# Response: Priority Choice: Repair Water Commercial in Community 2
#
# Reasoning: Given the information provided, it is clear that Community 2 has a larger population of 12,000 compared to Community 1 with 5,000. Additionally, Community 2 has a lower social vulnerability score of 4/10 compared to Community 1 with a score of 7/10. This indicates that Community 2 may be more stable and resilient in dealing with infrastructure issues.
#
# Repairing the Water Commercial infrastructure in Community 2 is crucial as it serves a larger population and is essential for commercial activities. Without access to clean water for businesses and industries in Community 2, economic activities could be severely disrupted, leading to potential financial losses for the community.
#
# Furthermore, Community 2 has moderate access to resources, which suggests that they may be better equipped to handle the repair of the Water Commercial infrastructure compared to Community 1, which has limited access to resources.
#
# As a local government employee with a background in addressing community needs and prioritizing infrastructure repair, my decision to repair Water Commercial in Community 2 is based on the larger population size, lower social vulnerability score, and moderate access to resources in that community. This choice aligns with the goal of ensuring the well-being and economic stability of the community as a whole.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Water Residential in Community 2?
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Local Government Employee with the information provided, my priority choice would be to repair the Water School in Community 1. While both communities are in need of water infrastructure repairs, the social vulnerability score in Community 1 is higher (7/10) compared to Community 2 (4/10). This means that Community 1 is more susceptible to negative impacts from lack of access to clean water, which can have serious consequences on the health and well-being of its residents.
#
# Additionally, Community 1 has a population of 5000, which is smaller than Community 2's population of 12000. Repairing the Water School in Community 1 would benefit a smaller, more vulnerable population in need of immediate assistance. Furthermore, the access to resources in Community 1 is limited, making it even more crucial to prioritize the repair of essential infrastructure like the Water School.
#
# While both communities are in need of attention, repairing the Water School in Community 1 aligns with the goal of addressing social vulnerability and ensuring access to clean water for a smaller, more vulnerable population with limited resources. This choice will have a more immediate and significant impact on the well-being of the community members in need.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Commercial in Community 2 or Water School in Community 3?
# Response: Priority Choice: Repair Water School in Community 3
#
# Reasoning: As a Local Government Employee with a background in assessing community needs and resources, I believe it is more critical to repair the Water School in Community 3 first. This decision is based on several factors. Firstly, Community 3 has a larger population of 20,000 compared to the 12,000 in Community 2. Repairing the Water School in Community 3 will have a greater impact on a larger number of individuals, including students, teachers, and staff who rely on the school for their daily needs.
#
# Secondly, Community 3 has a lower social vulnerability score of 2/10 compared to Community 2's score of 4/10. This means that Community 3 is less susceptible to negative impacts from infrastructure damage. By prioritizing the repair of the Water School in Community 3, we can ensure that the community remains resilient and can continue to thrive.
#
# Additionally, the access to resources in Community 3 is good, which suggests that there may be more support available for repairing the Water School compared to Community 2. As a Technology enthusiast, I understand the importance of leveraging resources effectively to address community needs.
#
# In conclusion, repairing the Water School in Community 3 aligns with the principles of equity, community impact, and resource optimization. This decision will benefit a larger population with higher vulnerability scores and better access to resources, ultimately contributing to the overall well-being and resilience of the community.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Residential in Community 1 or Water Residential in Community 2?
# Response: Priority Choice: Repair Water Residential in Community 2
#
# Reasoning: Based on the information provided, repairing Water Residential in Community 2 should be the priority. Community 2 has a larger population of 12,000 people compared to Community 1 with 5,000 people. This means that more individuals in Community 2 are directly impacted by the lack of access to clean water in their residential areas. Additionally, Community 2 has a lower social vulnerability score of 4/10 compared to Community 1 with a score of 7/10, indicating that Community 2 may have a harder time accessing resources to address their water infrastructure issues.
#
# Furthermore, Community 2 has moderate access to resources, while Community 1 has limited access. This suggests that Community 2 may have a better chance of receiving assistance or funding for the repairs needed. As a local government employee, it is important to prioritize the needs of the community with the higher population and lower social vulnerability score to ensure the well-being and safety of a larger number of residents. Repairing Water Residential in Community 2 aligns with this principle and is the more strategic choice.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 2 or Water Residential in Community 3?
# Response: Priority Choice: Repair Water Residential in Community 3
# Reasoning: Given the information provided, it is clear that Community 3 has the largest population among the three communities and has a lower social vulnerability score compared to the other two. Additionally, Community 3 also has good access to resources. Therefore, repairing the Water Residential infrastructure in Community 3 should be the priority as it will have a greater impact on a larger population with better access to resources. As a Local Government Employee with a background in addressing community needs, it is important to prioritize the repair of essential infrastructure in areas with higher population density and better access to resources to ensure the well-being and safety of the residents. Additionally, being a Technology enthusiast, I understand the importance of access to basic utilities such as water for the overall development and progress of a community.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 3 or Water Residential in Community 3?
# Response: Priority Choice: Repair Water Residential in Community 3
#
# Reasoning: As a Local Government Employee with a background in infrastructure management, I believe that repairing the Water Residential infrastructure in Community 3 should be the top priority. While both Power Residential and Water Residential are damaged in Community 3, access to clean and safe water is essential for the health and well-being of the residents. With a population of 20,000 and a social vulnerability score of 2/10, it is crucial to ensure that the residents have access to basic necessities like water.
#
# Additionally, the access to resources in Community 3 is good, which means that there are likely funds and materials available to address the repair of the Water Residential infrastructure. As a technology enthusiast, I understand the importance of having a reliable water supply for various technological advancements and innovations that may benefit the community.
#
# By prioritizing the repair of the Water Residential infrastructure in Community 3, we can improve the quality of life for the residents and ensure the sustainability and resilience of the community in the long run. Repairing the water infrastructure will also have positive ripple effects on other aspects of the community, such as public health, economic development, and overall well-being.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Water Residential in Community 3?
# Response: Priority Choice: Repair Water Residential in Community 3
#
# Reasoning: Given that the population of Community 3 is significantly larger than that of Community 1, it is crucial to prioritize the repair of the Water Residential infrastructure in Community 3. This is because access to clean water for residential purposes is essential for the health and well-being of a larger population. Additionally, the social vulnerability score of Community 3 is lower compared to Community 1, indicating that the residents of Community 3 may have a better ability to adapt to temporary inconveniences compared to the residents of Community 1. As a technology enthusiast, I understand the importance of access to resources in Community 3 and recognize that repairing the Water Residential infrastructure will have a greater overall impact on the community's quality of life. Therefore, I believe that repairing the Water Residential infrastructure in Community 3 should be prioritized over repairing the Water School in Community 1.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 2 or Water School in Community 3?
# Response: Priority Choice: Repair Power Residential in Community 2
#
# Reasoning: Given that I am a Local Government Employee and have access to information about all communities, I believe that repairing the Power Residential infrastructure in Community 2 should be the priority. Community 2 has a higher population of 12000 compared to Community 3's population of 20000. Additionally, Community 2 has a moderate level of social vulnerability compared to Community 3, which has a lower social vulnerability score of 2/10.
#
# Furthermore, access to resources in Community 2 is rated as moderate, indicating that the necessary materials and support may be more readily available for repairing the Power Residential infrastructure. Considering that Community 2 is a Technology enthusiast, having a functional power supply in residential areas is crucial for daily life and economic activities.
#
# While repairing the Water School in Community 3 is important for the education and well-being of the community, prioritizing the repair of Power Residential in Community 2 will have a more significant impact on a larger population with moderate social vulnerability and access to resources. This decision aligns with my role as a Local Government Employee to prioritize the needs of the community based on population, vulnerability, and available resources.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 1 or Water School in Community 3?
# Response: Priority Choice: Repair Power Residential in Community 1
#
# Reasoning: As a Local Government Employee, my priority choice would be to repair the Power Residential in Community 1. While both communities are in need of infrastructure repairs, Community 1 has a higher social vulnerability score of 7/10 compared to Community 3's score of 2/10. This means that the residents in Community 1 are more susceptible to negative impacts from infrastructure failures.
#
# Additionally, the population of Community 1 is smaller at 5000 residents, which means that the impact of power outages in residential areas would affect a smaller number of people compared to the larger population of 20000 in Community 3. Given the limited access to resources in Community 1, it is crucial to prioritize the repair of the Power Residential infrastructure to ensure the well-being and safety of the residents.
#
# Furthermore, considering the additional trait of being a Technology enthusiast, it is important to prioritize repairing the Power Residential infrastructure in Community 1 to ensure that residents have access to essential services and can also benefit from technological advancements that may rely on a stable power supply. Repairing this infrastructure will also help in improving the overall quality of life in Community 1.
# Valid response generated.
# Generating responses for Persona ID: P144, Occupation: Healthcare Worker
#
# Processing question: Which should be repaired first: Water Commercial in Community 2 or Power Residential in Community 3?
# Response: Priority Choice: Repair Water Commercial in Community 2
#
# Reasoning: As a Healthcare Worker and a caregiver for an elderly parent, my priority choice is to repair the Water Commercial infrastructure in Community 2 first. While both communities are in need of repairs, Community 2 has a larger population of 12000 compared to Community 3's population of 20000. Additionally, the social vulnerability score in Community 2 is higher at 4/10 compared to Community 3's score of 2/10.
#
# Water is essential for sanitation and hygiene, especially during this time when proper handwashing is crucial for preventing the spread of diseases. Repairing the Water Commercial infrastructure in Community 2 will ensure that a larger population has access to clean and safe water, reducing the risk of waterborne illnesses.
#
# Furthermore, as a caregiver for an elderly parent, I understand the importance of access to resources and the impact it can have on vulnerable populations. By prioritizing the repair of the Water Commercial infrastructure in Community 2, I am taking into consideration the needs of a larger population with a higher social vulnerability score, ensuring that basic needs such as access to clean water are met.
#
# Once the Water Commercial infrastructure in Community 2 is repaired, efforts can then be focused on addressing the power outage in the Residential area of Community 3. It is important to prioritize repairs based on population size, social vulnerability, and access to resources to ensure that the most pressing needs are addressed first.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 1 or Power Residential in Community 2?
# Response: Priority Choice: Repair Power Residential in Community 2
#
# Reasoning: As a healthcare worker and a caregiver for an elderly parent, I understand the importance of prioritizing the well-being and safety of vulnerable populations. In this case, Community 2 has a higher population of 12000 compared to Community 1's population of 5000. Additionally, Community 2 has a lower social vulnerability score of 4/10 compared to Community 1's score of 7/10. This means that Community 2 is less equipped to handle the effects of a power outage compared to Community 1.
#
# Furthermore, Community 2 has a moderate access to resources, which suggests that they may have some capacity to recover from the power outage with external assistance. On the other hand, Community 1 has limited access to resources, which could hinder their ability to bounce back from the outage quickly.
#
# Repairing Power Residential in Community 2 first would not only benefit a larger population but also a population with lower social vulnerability. This decision is in line with my background as a healthcare worker, where the well-being of the community and its residents is of utmost importance.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 3 or Water Residential in Community 3?
# Response: Priority Choice: Repair Water Residential in Community 3
# Reasoning: As a healthcare worker, my priority would be to repair the Water Residential infrastructure in Community 3. Water is a basic necessity for human survival, and ensuring access to clean water is crucial for maintaining the health and well-being of the residents in this community. With a population of 20,000 and good access to resources, it is important to prioritize the repair of the Water Residential infrastructure to prevent any potential health hazards or waterborne diseases. Additionally, as a caregiver for an elderly parent, I understand the importance of having reliable access to clean water for vulnerable populations. Repairing the Water Residential infrastructure will not only benefit the immediate community but also contribute to overall public health and safety.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 1 or Power Residential in Community 3?
# Response: Priority Choice: Repair Power Residential in Community 3
#
# Reasoning: As a healthcare worker and a caregiver for an elderly parent, my priority would be to repair Power Residential in Community 3. This community has a larger population of 20,000 people and a lower social vulnerability score of 2/10 compared to Community 1. Additionally, Community 3 has good access to resources which can aid in the repair process and provide support for the residents.
#
# By prioritizing the repair of Power Residential in Community 3, we can ensure that a larger number of individuals have access to essential services such as electricity for medical equipment, heating, and cooling. This can significantly impact the health and well-being of the residents, especially vulnerable populations such as the elderly.
#
# While Community 1 also requires repairs, the smaller population size of 5,000 and limited access to resources may make it more feasible to address their needs after addressing the larger and more resource-rich Community 3. Repairing Power Residential in Community 3 first can have a greater overall impact on the health and safety of a larger number of individuals in need.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Commercial in Community 2 or Water School in Community 3?
# Response: Priority Choice: Repair Water School in Community 3
#
# Reasoning: As a healthcare worker, my main concern is the health and well-being of the residents in the communities. In this scenario, Community 3 has a larger population of 20,000 people compared to Community 2 with 12,000 people. Additionally, Community 3 has a lower social vulnerability score of 2/10, indicating that the residents may have better access to healthcare services.
#
# Repairing the Water School in Community 3 should be the priority as education plays a crucial role in public health. Without access to clean water in the school, children may be at risk of waterborne diseases which can lead to absenteeism and poor academic performance. Furthermore, the school serves as a hub for the community and provides essential services such as meals and healthcare to students.
#
# Although repairing the Water Commercial in Community 2 is important for the residents' daily needs, the larger population size and lower social vulnerability score of Community 3 make it a higher priority. Additionally, the fact that I am a caregiver for an elderly parent emphasizes the importance of prioritizing the health and well-being of the larger community. Repairing the Water School in Community 3 will have a more significant impact on the overall health and education of the residents in the long run.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Residential in Community 1 or Power Residential in Community 3?
# Response: Priority Choice: Repair Water Residential in Community 1
# Reasoning: As a healthcare worker and a caregiver for an elderly parent, my priority would be to repair the water infrastructure in Community 1. Water is essential for basic hygiene, sanitation, and overall health. Without access to clean water, the residents of Community 1 are at risk of waterborne diseases and other health issues. Additionally, the population in Community 1 is smaller compared to Community 3, which means that the impact of repairing the water infrastructure in Community 1 would be more immediate and significant for the residents. Considering the limited access to resources in Community 1 and the social vulnerability score of 7/10, it is crucial to prioritize the repair of water infrastructure to ensure the health and well-being of the community members, especially during times of crisis.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Residential in Community 2 or Water School in Community 3?
# Response: Priority Choice: Repair Water School in Community 3
#
# Reasoning: As a healthcare worker and a caregiver for an elderly parent, I understand the importance of access to clean water for both community health and individual well-being. While both the residential water in Community 2 and the school water in Community 3 are in need of repair, I believe that repairing the water supply for the school in Community 3 should take priority.
#
# Community 3 has a larger population of 20,000 compared to Community 2's population of 12,000. This means that a larger number of individuals, including children and teachers, rely on the water supply at the school in Community 3. Ensuring that the school has access to clean water is crucial for maintaining a healthy learning environment and preventing the spread of waterborne illnesses among students and staff.
#
# Additionally, Community 3 has a lower social vulnerability score of 2/10 compared to Community 2's score of 4/10. This suggests that Community 3 may have more resources and capacity to address the water supply issue in the long term. By prioritizing the repair of the water supply at the school in Community 3, we can help ensure the health and well-being of a larger population with potentially greater resources to sustain the repair in the future.
#
# Overall, repairing the water supply at the school in Community 3 aligns with my background as a healthcare worker and caregiver, as it prioritizes the health and safety of a larger community with potentially more resources to address the issue effectively.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Power Residential in Community 1?
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Healthcare Worker, my priority is the overall health and well-being of the community members. In this case, repairing the Water School in Community 1 should take precedence over repairing Power Residential. Access to clean and safe water is crucial for the health of the community, especially for the children who attend the school. Without proper water facilities, the risk of waterborne diseases and contamination is high, which can have severe consequences on the health of the residents.
#
# Additionally, considering the social vulnerability score of Community 1 (7/10) and the limited access to resources, addressing the water issue at the school can have a more significant impact on the community's health and overall well-being. Repairing the Water School will not only benefit the students and teachers but also the surrounding residents who may rely on the school for clean water access.
#
# While repairing Power Residential is important for the comfort and convenience of the residents, the immediate health impact of addressing the water issue at the school outweighs the benefits of fixing the power infrastructure. In this scenario, prioritizing the repair of the Water School aligns with my background as a Healthcare Worker and my commitment to promoting the health and safety of the community members.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Water Residential in Community 1?
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a healthcare worker, my priority is to ensure the health and well-being of the community members. In this scenario, repairing the Water School in Community 1 should be the first priority. Education is essential for the development and future of the community, and a functioning water supply at the school is crucial for maintaining proper hygiene and sanitation practices among the students and staff. Without access to clean water, the risk of waterborne diseases and illnesses increases, which can have a significant impact on the health of the entire community, including vulnerable populations such as children.
#
# While repairing the water residential infrastructure is also important for the overall well-being of the community, prioritizing the Water School will not only benefit the current population but also future generations by ensuring a healthy learning environment. Additionally, the social vulnerability score of Community 1 is higher compared to the other communities, indicating a greater need for support and resources. Therefore, addressing the water supply issue at the school will have a more immediate and wide-reaching impact on the health and safety of the community members.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 1 or Water Residential in Community 2?
# Response: Priority Choice: Repair Water Residential in Community 2
#
# Reasoning: As a healthcare worker with a background in caring for vulnerable populations, including the elderly, I understand the importance of access to clean water for basic hygiene, hydration, and overall health. Community 2 has a larger population of 12000 compared to Community 1's population of 5000. Additionally, Community 2 has a lower social vulnerability score of 4/10 compared to Community 1's score of 7/10. Repairing the water infrastructure in Community 2 will benefit a larger number of residents and help improve their overall health and well-being. Furthermore, with moderate access to resources in Community 2, the repair of the water residential infrastructure is more feasible and likely to have a quicker impact on the community.
# Valid response generated.
# Generating responses for Persona ID: P145, Occupation: Medical Doctor
#
# Processing question: Which should be repaired first: Power Residential in Community 2 or Water Residential in Community 2?
# Response: Priority Choice: Repair Water Residential in Community 2
#
# Reasoning: In Community 2, the Water Residential infrastructure is damaged, affecting the access to clean water for a population of 12000. Water is essential for hydration, sanitation, and overall health. Without access to clean water, the community is at risk of waterborne diseases and other health issues. As a Medical Doctor, I prioritize the repair of Water Residential in Community 2 to ensure the well-being and health of the residents. Once access to clean water is restored, efforts can then be focused on repairing the Power Residential infrastructure.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Water School in Community 3?
# Response: Priority Choice: Repair Water School in Community 3
# Reasoning: As a Medical Doctor with a background in public health, I believe that repairing the Water School in Community 3 should be the priority. Community 3 has a larger population of 20,000 people compared to Community 1 with 5,000 people. Additionally, Community 3 has a lower social vulnerability score of 2/10, indicating that they are less vulnerable and more resilient to potential health risks associated with inadequate access to clean water.
#
# Furthermore, Community 3 has good access to resources, which means that they may have the means to address their own health needs if provided with the necessary infrastructure. By repairing the Water School in Community 3 first, we can ensure that a larger population has access to clean water, which is essential for preventing waterborne diseases and promoting overall health and well-being.
#
# Although Community 1 also has a damaged Water School, the smaller population size and higher social vulnerability score suggest that they may require additional support in addressing their health needs. Therefore, focusing on repairing the Water School in Community 3 first would have a greater impact on improving public health outcomes in the long run.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 1 or Power Residential in Community 2?
# Response: Priority Choice: Repair Power Residential in Community 2
#
# Reasoning: Given the information provided, Community 2 has a larger population of 12,000 compared to Community 1's population of 5,000. Additionally, Community 2 has a lower social vulnerability score of 4/10 compared to Community 1's score of 7/10. This indicates that Community 2 may be more equipped to handle the challenges of a power outage in the residential area. Furthermore, Community 2 has moderate access to resources, which suggests that they may have more support in dealing with the power outage.
#
# As a Medical Doctor, I understand the importance of ensuring that essential services like power are restored in a timely manner to prevent any negative health impacts on the community. By prioritizing the repair of Power Residential in Community 2, we can ensure that a larger population with relatively lower social vulnerability is able to have access to basic necessities and maintain their quality of life.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Commercial in Community 2 or Power Residential in Community 3?
# Response: Priority Choice: Repair Water Commercial in Community 2
#
# Reasoning: As a Medical Doctor and considering the information provided, my priority choice would be to repair the Water Commercial infrastructure in Community 2. Although Community 3 has a larger population, repairing the Water Commercial in Community 2 is essential due to the high population of 12000 and the limited access to resources. Water is a basic necessity for human survival and the commercial infrastructure in this community is crucial for providing clean water to a significant number of people. Additionally, the social vulnerability score of 4/10 suggests that the residents of Community 2 may face challenges in accessing resources independently. By repairing the Water Commercial infrastructure in Community 2, we can ensure that a larger number of people have access to clean water, which is vital for maintaining public health and preventing waterborne diseases.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Residential in Community 1 or Water Commercial in Community 2?
# Response: Priority Choice: Repair Water Residential in Community 1
# Reasoning: As a Medical Doctor, I prioritize the repair of Water Residential in Community 1 due to the high social vulnerability score of 7/10 and limited access to resources in this community. Water is a basic necessity for human survival and without access to clean water in residential areas, the health and well-being of the population can be severely compromised. Additionally, the population of Community 1 is 5000, which although smaller than Community 2, still represents a significant number of individuals who are in need of immediate assistance. By repairing the water infrastructure in Community 1, we can address the urgent health needs of the residents and prevent potential waterborne diseases. While the water infrastructure in Community 2 also needs repair, the lower social vulnerability score of 4/10 and moderate access to resources indicate that the population may be better equipped to cope with the temporary disruption in water supply. Therefore, focusing on repairing Water Residential in Community 1 is the most critical and compassionate choice in this situation.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Water Commercial in Community 2?
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Medical Doctor, I understand the importance of access to clean water for overall community health. In Community 1, the Water School is damaged, which means that children in the community are not able to access safe drinking water and proper sanitation facilities. This can lead to a higher risk of waterborne diseases and overall poor health outcomes among the population, especially the vulnerable children.
#
# Although Community 2 also has a damaged Water Commercial infrastructure, the larger population size in Community 2 means that the impact of repairing the Water School in Community 1 will likely be more significant in terms of improving overall health outcomes. Additionally, the social vulnerability score in Community 1 is higher compared to Community 2, indicating a greater need for immediate intervention.
#
# Therefore, repairing the Water School in Community 1 should be prioritized to ensure that the community has access to safe drinking water and sanitation facilities, ultimately improving the health and well-being of its residents, particularly the children.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 2 or Water School in Community 3?
# Response: Priority Choice: Repair Water School in Community 3
# Reasoning: As a Medical Doctor with a background in public health, I believe that repairing the Water School in Community 3 should be the priority. The Water School serves a larger population (20000) compared to the Power Residential in Community 2 (12000) and plays a crucial role in providing clean and safe water to the community. Without access to clean water, the risk of waterborne diseases and other health issues increases significantly. Additionally, Community 3 has a lower social vulnerability score (2/10) compared to Community 2 (4/10), indicating that the residents of Community 3 may have fewer resources to cope with the lack of clean water. By repairing the Water School in Community 3 first, we can ensure the health and well-being of a larger population and address the immediate health risks associated with the lack of clean water.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Power Residential in Community 1?
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Medical Doctor, I understand the importance of access to clean water for overall community health and well-being. Repairing the Water School in Community 1 should be the priority because it not only impacts the education and daily lives of the children in the community but also has a direct impact on their health. Without access to clean water for drinking, sanitation, and hygiene, the risk of waterborne diseases and other health issues increases significantly. Additionally, by repairing the Water School, the community can benefit from improved hygiene practices and education on water-related diseases, ultimately leading to a healthier population. While repairing Power Residential in Community 1 is important for providing electricity to residents, the immediate health impact of repairing the Water School takes precedence in this scenario.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 2 or Power Residential in Community 3?
# Response: Priority Choice: Repair Power Residential in Community 2
#
# ...
#
# While both communities are in need of repair, the larger population in Community 2 and the potential for more severe consequences in the absence of water make it the more urgent choice. Furthermore, the social vulnerability score of 4/10 indicates that this community may already be facing some challenges, and repairing the water infrastructure would help alleviate some of these issues.
#
# By prioritizing the repair of the Water Residential infrastructure in Community 2, we can ensure the well-being and safety of a larger population and contribute to building a more resilient and sustainable community in the face of climate change.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 2 or Water Residential in Community 3?
# Response: Priority Choice: Repair Power Residential in Community 2
#
# Reasoning: Given that I am a Small Business Owner with a background in climate change activism, I believe it is crucial to prioritize repairing the Power Residential infrastructure in Community 2. With a population of 12,000 and moderate access to resources, Community 2 has a larger number of residents who depend on reliable power supply for their daily activities and businesses.
#
# Furthermore, as a climate change activist, I understand the importance of ensuring sustainable and resilient infrastructure to withstand future environmental challenges. By repairing the Power Residential infrastructure in Community 2, we can not only provide essential services to a significant number of people but also contribute to building a more sustainable and resilient community in the face of climate change.
#
# While repairing the Water Residential infrastructure in Community 3 is also important, the lower social vulnerability score and better access to resources in Community 3 indicate that the residents may have alternative sources of water supply or temporary solutions in place. Therefore, prioritizing the repair of Power Residential in Community 2 would have a greater impact on the overall well-being and economic stability of the community.
# Valid response generated.
# Generating responses for Persona ID: P200, Occupation: Nurse
#
# Processing question: Which should be repaired first: Water Residential in Community 2 or Water School in Community 3?
# Response: Priority Choice: Repair Water Residential in Community 2
#
# Reasoning: Community 2 has a larger population of 12,000 compared to Community 3's population of 20,000. However, Community 2 has a higher social vulnerability score of 4/10 compared to Community 3's score of 2/10. This means that Community 2 is more at risk and in greater need of immediate assistance. Additionally, access to resources in Community 2 is only moderate, while Community 3 has good access to resources. By repairing the Water Residential infrastructure in Community 2 first, we can ensure that a larger population with higher vulnerability has access to clean water for drinking, cooking, and sanitation. This can help prevent the spread of waterborne illnesses and improve overall community health. Additionally, with a functioning Water Residential system in Community 2, resources can then be allocated to repairing the Water School infrastructure in Community 3, which has a lower social vulnerability score and better access to resources.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Water Residential in Community 3?
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Nurse, my priority is the health and well-being of the community members. In Community 1, the Water School is damaged, which means that the children in the community do not have access to clean water for drinking, washing hands, and maintaining proper hygiene. This can lead to the spread of waterborne diseases and other health issues among the vulnerable population of 5000 people with a social vulnerability score of 7/10.
#
# While repairing the Water Residential in Community 3 is important for the 20000 residents, they have good access to resources and might be able to find alternative sources of clean water temporarily. On the other hand, the children in Community 1 are dependent on the Water School for their daily water needs and cannot easily find alternatives. Therefore, repairing the Water School in Community 1 should be the priority to ensure the health and safety of the community members.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Residential in Community 1 or Water Commercial in Community 2?
# Response: Priority Choice: Repair Water Residential in Community 1
#
# Reasoning: As a Nurse, I prioritize the health and well-being of individuals, and access to clean water is essential for maintaining good health. In this scenario, repairing the water infrastructure in Community 1 should be the top priority because it directly impacts the residential area where people live. With a population of 5000 and a social vulnerability score of 7/10, the residents of Community 1 are more at risk due to limited access to resources. By repairing the water infrastructure in the residential area, we can ensure that the residents have access to safe and clean water for drinking, cooking, and sanitation purposes.
#
# On the other hand, while repairing the water infrastructure in the commercial area of Community 2 is important for businesses and economic activities, it does not directly impact the well-being of individuals in the same way as access to clean water in residential areas does. Additionally, Community 2 has a larger population of 12000 and a lower social vulnerability score of 4/10, indicating that they may have more resources and resilience to cope with the temporary inconvenience of a water supply issue.
#
# Overall, prioritizing the repair of water infrastructure in Community 1 will have a more significant impact on the health and safety of residents who are more vulnerable due to limited access to resources. It is important to address the immediate needs of those most at risk in order to prevent potential health crises in the community.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 1 or Power Residential in Community 3?
# Response: Priority Choice: Repair Power Residential in Community 1
#
# Reasoning: Community 1 has a smaller population compared to Community 3, with only 5000 residents. However, the social vulnerability score is higher in Community 1 at 7/10, indicating a higher level of vulnerability and need for support. Additionally, access to resources in Community 1 is limited, making it more challenging for residents to cope with the lack of power in their residential area.
#
# On the other hand, while Community 3 has a larger population of 20000 residents, their social vulnerability score is lower at 2/10 and they have good access to resources. This suggests that residents in Community 3 may have better means to cope with the power outage in their residential area compared to those in Community 1.
#
# Therefore, repairing Power Residential in Community 1 should be the priority as the residents are more vulnerable and have limited resources to address their needs. This decision is based on my background as a nurse, where I prioritize the well-being and safety of individuals in vulnerable communities.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 3 or Water Residential in Community 3?
# Response: Priority Choice: Repair Water Residential in Community 3
# Reasoning: Given that Community 3 has a larger population of 20,000 and good access to resources, it is crucial to prioritize repairing the Water Residential infrastructure in this community. Access to clean water is essential for basic hygiene, sanitation, and overall health of the residents. Without functioning water infrastructure, the community may face potential health risks and waterborne diseases. Additionally, with a larger population, the impact of a lack of water supply would be more severe in Community 3 compared to Community 1 or 2. Therefore, repairing the Water Residential infrastructure in Community 3 should be the priority to ensure the well-being of the residents.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Power Residential in Community 3?
# Response: Priority Choice: Repair Water School in Community 1
# Reasoning: As a Nurse, I understand the importance of access to clean water and sanitation in maintaining community health. The Water School in Community 1 serves a population of 5000, which includes vulnerable individuals who may be more susceptible to waterborne diseases if they do not have access to clean water. Additionally, with limited access to resources in Community 1, it is crucial to prioritize repairing the Water School to ensure that the residents have a safe and healthy environment for learning and daily activities. While repairing the Power Residential in Community 3 is important for the residents' daily living needs, the immediate health impact of repairing the Water School in Community 1 takes precedence in this situation.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Power Residential in Community 2?
# Response: Priority Choice: Repair Water School in Community 1
# Reasoning: As a Nurse, my primary concern is the health and well-being of the community members. In Community 1, the Water School is a critical infrastructure that provides access to clean and safe drinking water for the children and staff. Without proper water supply, the risk of waterborne diseases and contamination is high, which can have a direct impact on the overall health of the population. Additionally, with a social vulnerability score of 7/10 and limited access to resources, the residents of Community 1 are already facing challenges in meeting their basic needs. By prioritizing the repair of the Water School, we can ensure that the most vulnerable members of the community have access to a vital resource for their health and well-being. Repairing the Water School in Community 1 will have a direct and immediate impact on the health and safety of the residents, making it the most urgent repair priority.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Water Commercial in Community 2?
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: In this scenario, the priority should be given to repairing the Water School in Community 1. While both communities are in need of water infrastructure repairs, Community 1 has a higher social vulnerability score of 7/10 compared to Community 2's score of 4/10. This indicates that Community 1 is more susceptible to the negative impacts of damaged infrastructure, such as lack of access to clean water and sanitation facilities. Additionally, Community 1 has a smaller population of 5000, which means that the impact of repairing the Water School will be more concentrated and beneficial to a larger percentage of the population.
#
# Furthermore, access to resources in Community 1 is limited, which means that the residents may struggle to find alternative solutions for accessing clean water if the Water School is not repaired promptly. On the other hand, Community 2 has moderate access to resources, which suggests that they may have more options available to them while waiting for repairs to be completed.
#
# Overall, prioritizing the repair of the Water School in Community 1 will not only address the immediate needs of a vulnerable population but also help prevent potential health risks associated with the lack of clean water. It is crucial to consider the social vulnerability and limited resources of Community 1 when making this decision.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 1 or Power Residential in Community 2?
# Response: Priority Choice: Repair Power Residential in Community 2
#
# Reasoning: I choose to repair Power Residential in Community 2 first because it has a larger population of 12000 compared to Community 1's population of 5000. This means that more people are affected by the lack of power in Community 2. Additionally, Community 2 has a lower social vulnerability score of 4/10 compared to Community 1's score of 7/10. This indicates that Community 2 may have a harder time coping with the lack of power due to their limited access to resources. By prioritizing the repair of Power Residential in Community 2, we can ensure that a larger number of people have access to essential services and can improve their overall well-being.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 1 or Water Residential in Community 2?
# Response: Priority Choice: Repair Power Residential in Community 1
#
# Reasoning: As a Nurse, my priority choice would be to repair the Power Residential infrastructure in Community 1 first. While both communities are in need of urgent repairs, Community 1 has a higher social vulnerability score of 7/10 compared to Community 2's score of 4/10. With a smaller population of 5000 in Community 1, the impact of a lack of power infrastructure on essential services such as healthcare facilities and emergency response would be more severe.
#
# Furthermore, Community 1 has limited access to resources, making it more challenging for residents to cope with the lack of power in their residential area. By prioritizing the repair of Power Residential in Community 1, we can ensure that essential services are restored promptly and address the immediate needs of the vulnerable population in this community.
#
# While repairing the Water Residential infrastructure in Community 2 is also crucial, the larger population of 12000 and moderate access to resources make it slightly less urgent in comparison to Community 1. Ultimately, prioritizing the repair of Power Residential in Community 1 will have a more significant impact on the overall well-being and safety of the residents in this community.
# Valid response generated.
#
# Persona and Response information has been written to personas_and_responses.csv
#
# Generated 2000 total responses.
#      response_id persona_id    community                 occupation  \
# 0           R001       P001  Community 1  Local Government Employee
# 1           R002       P001  Community 1  Local Government Employee
# 2           R003       P001  Community 1  Local Government Employee
# 3           R004       P001  Community 1  Local Government Employee
# 4           R005       P001  Community 1  Local Government Employee
# ...          ...        ...          ...                        ...
# 1995       R1996       P200  Community 3                      Nurse
# 1996       R1997       P200  Community 3                      Nurse
# 1997       R1998       P200  Community 3                      Nurse
# 1998       R1999       P200  Community 3                      Nurse
# 1999       R2000       P200  Community 3                      Nurse
#
#                               priority_choice
# 0          Repair Water School in Community 3
# 1     Repair Water Residential in Community 1
# 2     Repair Power Residential in Community 1
# 3     Repair Water Residential in Community 3
# 4     Repair Water Residential in Community 2
# ...                                       ...
# 1995       Repair Water School in Community 1
# 1996       Repair Water School in Community 1
# 1997       Repair Water School in Community 1
# 1998  Repair Power Residential in Community 2
# 1999  Repair Power Residential in Community 1
#
# [2000 rows x 5 columns]

# %% [markdown]
# ##Dataset cleaning

# %%
import pandas as pd
import ast

# Define community contexts
community_contexts = {
    "Community 1": {
        "community_id": "C001",
        "social_vulnerability_score": 7,
        "access_to_resources": "Limited",
        "population": 5000
    },
    "Community 2": {
        "community_id": "C002",
        "social_vulnerability_score": 4,
        "access_to_resources": "Moderate",
        "population": 12000
    },
    "Community 3": {
        "community_id": "C003",
        "social_vulnerability_score": 2,
        "access_to_resources": "Good",
        "population": 20000
    }
}

# Read the CSV file
df = pd.read_csv('community_focused_data_run2.csv')

# Function to get community attributes
def get_community_attributes(community):
    return community_contexts.get(community, {})

# Process the dataframe
def process_dataframe(df):
    # Get community attributes
    community_attributes = df['community'].apply(get_community_attributes)

    # Update dataframe with community attributes
    df['community_id'] = community_attributes.apply(lambda x: x.get('community_id', ''))
    df['population'] = community_attributes.apply(lambda x: x.get('population', ''))
    df['social_vulnerability_score'] = community_attributes.apply(lambda x: x.get('social_vulnerability_score', ''))
    df['access_to_resources'] = community_attributes.apply(lambda x: x.get('access_to_resources', ''))

    # Convert social vulnerability score to a 0-1 scale
    df['social_vulnerability_score'] = df['social_vulnerability_score'] / 10

    # Encode access to resources
    resource_mapping = {'Limited': 0, 'Moderate': 1, 'Good': 2}
    df['access_to_resources'] = df['access_to_resources'].map(resource_mapping)

    # Ensure 'ordered_pair' is a list
    df['ordered_pair'] = df['ordered_pair'].apply(ast.literal_eval)

    # Create separate columns for option1 and option2 from ordered_pair
    df['option1_from_pair'] = df['ordered_pair'].apply(lambda x: x[0])
    df['option2_from_pair'] = df['ordered_pair'].apply(lambda x: x[1])

    # Reorder columns
    column_order = [
        'persona_id', 'community', 'population', 'social_vulnerability_score', 'access_to_resources',
        'question_id', 'option1', 'option2', 'priority_choice', 'ordered_pair',
    ]

    return df[column_order]

# Process the dataframe
df_processed = process_dataframe(df)

# Save the processed dataframe to a new CSV file
df_processed.to_csv('community_focused_data.csv', index=False)

print("Data has been processed and saved to 'community_focused_data.csv'")
# Out:
# Data has been processed and saved to 'community_focused_data.csv'
