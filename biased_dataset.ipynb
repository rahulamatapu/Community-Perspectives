# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulamatapu/Community-Perspectives/blob/master/biased_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install langchain langchain_experimental openai
# !pip install -U langchain-openai

from langchain_openai import ChatOpenAI
# set environment variables
# https://platform.openai.com/account/api-keys
import os
os.environ["OPENAI_API_KEY"] = ""


from langchain.prompts import FewShotPromptTemplate, PromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain.pydantic_v1 import BaseModel
from langchain_experimental.tabular_synthetic_data.base import SyntheticDataGenerator
from langchain_experimental.tabular_synthetic_data.openai import create_openai_data_generator, OPENAI_TEMPLATE
from langchain_experimental.tabular_synthetic_data.prompts import SYNTHETIC_FEW_SHOT_SUFFIX, SYNTHETIC_FEW_SHOT_PREFIX

# %%
import random
import itertools
from pydantic import BaseModel, Field
from pydantic import ConfigDict
from typing import Optional
from typing import List
from langchain_experimental.tabular_synthetic_data.openai import create_openai_data_generator
from langchain_core.prompts import FewShotPromptTemplate, PromptTemplate
from langchain_openai import ChatOpenAI

# %%
from typing import List, Dict, Tuple
from pydantic.v1 import BaseModel
# Scenario Information


# Persona Information
class PersonaInformation(BaseModel):
    persona_id: str
    community: str
    age: int
    occupation: str
    household_composition: str
    disaster_experience: str
    socioeconomic_status: str
    community_description: str


# Response Data
    class Config:
        arbitrary_types_allowed = True

class ResponseData(BaseModel):
    response_id: str
    scenario_id: str
    persona_id: str
    question_id: str
    option1: str
    option2: str
    priority_choice: str
    reasoning: str
    ordered_pair: List[str]

# Scenario Context
'''
class ScenarioContext(BaseModel):
    scenario_id: str
    description: str
    model_config = ConfigDict(arbitrary_types_allowed=True)
'''
# Community Context
class CommunityContext(BaseModel):
    community_id: str
    social_vulnerability_score: int
    access_to_resources: str
    population: int

# Question, we generate questions seperately below using a script
class Question(BaseModel):
    question_id: str
    option1: str
    option2: str
    text: str

# %%
community_contexts = {
    "Community 1": CommunityContext(
        community_id="C001",
        social_vulnerability_score=7,
        access_to_resources="Limited",
        population=5000
    ),
    "Community 2": CommunityContext(
        community_id="C002",
        social_vulnerability_score=4,
        access_to_resources="Moderate",
        population=12000
    ),
    "Community 3": CommunityContext(
        community_id="C003",
        social_vulnerability_score=2,
        access_to_resources="Good",
        population=20000
    )
}

infrastructure_status = {
    "Community 1": {
        "Power School": 1, "Water School": 0, "Power House": 1, "Water House": 1,
        "Power Residential": 0, "Water Residential": 0, "Power Commercial": 1, "Water Commercial": 1
    },
    "Community 2": {
        "Power School": 1, "Water School": 1, "Power House": 1, "Water House": 1,
        "Power Residential": 0, "Water Residential": 0, "Power Commercial": 1, "Water Commercial": 0
    },
    "Community 3": {
        "Power School": 1, "Water School": 0, "Power House": 1, "Water House": 1,
        "Power Residential": 0, "Water Residential": 0, "Power Commercial": 1, "Water Commercial": 1
    }
}

# %%
def generate_community_description(community, status, context):
    working = [k for k, v in status.items() if v == 1]
    damaged = [k for k, v in status.items() if v == 0]
    return f"In {community}: " \
           f"- Working infrastructure: {', '.join(working)}; " \
           f"- Damaged infrastructure: {', '.join(damaged)}; " \
           f"- Population: {context.population}; " \
           f"- Social vulnerability score: {context.social_vulnerability_score}/10; " \
           f"- Access to resources: {context.access_to_resources}."


def generate_all_possible_questions():
    all_damaged = []
    for community, status in infrastructure_status.items():
        damaged = [(community, infra) for infra, working in status.items() if working == 0]
        all_damaged.extend(damaged)

    all_combinations = list(itertools.combinations(all_damaged, 2))

    questions = []
    for i, pair in enumerate(all_combinations, 1):
        question = Question(
            question_id=f"Q{i:03d}",
            option1=f"Repair {pair[0][1]} in {pair[0][0]}",
            option2=f"Repair {pair[1][1]} in {pair[1][0]}",
            text=f"Which should be repaired first: {pair[0][1]} in {pair[0][0]} or {pair[1][1]} in {pair[1][0]}?"
        )
        questions.append(question)

    return questions

def validate_response(response: ResponseData, persona: PersonaInformation, question: Question) -> Tuple[bool, str]:
    if response.priority_choice not in [question.option1, question.option2]:
        return False, f"Invalid priority choice: {response.priority_choice}"
    if set(response.ordered_pair) != set([question.option1, question.option2]):
        return False, f"Invalid ordered pair: {response.ordered_pair}"
    if persona.community not in response.reasoning:
        return False, f"Community {persona.community} not mentioned in reasoning"
    if persona.occupation.lower() not in response.reasoning.lower():
        return False, f"Occupation {persona.occupation} not mentioned in reasoning"
    return True, "Valid response"

# %%
OPENAI_TEMPLATE = PromptTemplate(input_variables=["example"], template="{example}")

persona_examples = [
    {
        "example": """Persona ID: P001, Community: Community 1, Age: 35, Occupation: Teacher,
        Household Composition: Married with children, Disaster Experience: Experienced a flood 5 years ago,
        Socioeconomic Status: Middle class, Community Description: Population 5000, Social vulnerability score 7/10,
        Limited access to resources"""
    },
    {
        "example": """Persona ID: P002, Community: Community 2, Age: 52, Occupation: Nurse,
        Household Composition: Single, Disaster Experience: No major disaster experience,
        Socioeconomic Status: Middle class, Community Description: Population 12000, Social vulnerability score 4/10,
        Moderate access to resources"""
    },
    {
        "example": """Persona ID: P003, Community: Community 3, Age: 68, Occupation: Retired,
        Household Composition: Married, Disaster Experience: Survived a hurricane last year,
        Socioeconomic Status: Upper middle class, Community Description: Population 20000, Social vulnerability score 2/10,
        Good access to resources"""
    },
]

response_examples = [
    {
        "example": """Response ID: R001, Scenario ID: S001, Persona ID: P001, Question ID: Q001,
        Option 1: Repair Water School in Community 1, Option 2: Repair Power Residential in Community 2,
        Priority Choice: Repair Water School in Community 1,
        Reasoning: As a teacher in Community 1, I believe access to clean water in schools is crucial for maintaining hygiene and preventing the spread of diseases, especially after a disaster. Our community has limited resources and a high social vulnerability score, so ensuring our schools are operational is a top priority for education continuity and community resilience.
        Ordered Pair: ["Repair Water School in Community 1", "Repair Power Residential in Community 2"]"""
    },
    {
        "example": """Response ID: R002, Scenario ID: S001, Persona ID: P002, Question ID: Q002,
        Option 1: Repair Power Residential in Community 2, Option 2: Repair Water Residential in Community 3,
        Priority Choice: Repair Power Residential in Community 2,
        Reasoning: As a nurse in Community 2, I understand the critical importance of electrical power for medical equipment and maintaining communication during emergencies. Our community has moderate access to resources, and restoring power to residential areas will help more people in our larger population of 12,000 to manage their health needs at home, potentially reducing strain on medical facilities.
        Ordered Pair: ["Repair Power Residential in Community 2", "Repair Water Residential in Community 3"]"""
    },
    {
        "example": """Response ID: R003, Scenario ID: S001, Persona ID: P003, Question ID: Q003,
        Option 1: Repair Water Residential in Community 1, Option 2: Repair Power School in Community 3,
        Priority Choice: Repair Water Residential in Community 1,
        Reasoning: As a retired person living in Community 3, I recognize the dire need for water in residential areas of Community 1. Although I'm from a community with good access to resources, I believe we should prioritize the basic needs of the most vulnerable. Community 1 has a higher social vulnerability score and limited access to resources, making clean water for their homes a critical priority for health and sanitation.
        Ordered Pair: ["Repair Water Residential in Community 1", "Repair Power School in Community 3"]"""
    },
    {
        "example": """Response ID: R004, Scenario ID: S001, Persona ID: P004, Question ID: Q004,
        Option 1: Repair Power Commercial in Community 2, Option 2: Repair Water School in Community 3,
        Priority Choice: Repair Power Commercial in Community 2,
        Reasoning: As a small business owner in Community 2, I believe restoring power to commercial areas is crucial for economic recovery after a disaster. Our community has a moderate population of 12,000 and restoring commercial power will help businesses reopen, provide essential services, and support the local economy. This can indirectly benefit the entire region by maintaining supply chains and employment.
        Ordered Pair: ["Repair Power Commercial in Community 2", "Repair Water School in Community 3"]"""
    },
    {
        "example": """Response ID: R005, Scenario ID: S001, Persona ID: P005, Question ID: Q005,
        Option 1: Repair Water Commercial in Community 1, Option 2: Repair Power Residential in Community 3,
        Priority Choice: Repair Water Commercial in Community 1,
        Reasoning: As a public health official in Community 1, I prioritize repairing the water supply to commercial areas in our community. Given our high social vulnerability score of 7/10 and limited access to resources, restoring water to commercial areas will allow essential businesses like pharmacies and food stores to operate, supporting the basic needs of our 5,000 residents. This is critical for preventing secondary health crises in our vulnerable population.
        Ordered Pair: ["Repair Water Commercial in Community 1", "Repair Power Residential in Community 3"]"""
    }
]

# Create prompt templates
OPENAI_TEMPLATE = PromptTemplate(input_variables=["example"], template="{example}")

persona_prompt_template = FewShotPromptTemplate(
    prefix=SYNTHETIC_FEW_SHOT_PREFIX + """
    Generate diverse personas for a disaster scenario study. Ensure variety in:
    - Age: Include a range from teenagers to elderly (16-80+)
    - Occupations: Vary widely, including unemployed and students
    - Household compositions: Include single parents, multigenerational households, etc.
    - Disaster experiences: Some with no experience, others with various past experiences
    - Socioeconomic statuses: Ensure representation across all economic levels
    - Physical abilities: Include some personas with disabilities
    - Cultural backgrounds: Represent diverse ethnicities and cultural practices
    - Length of residency in the community: Mix of newcomers and long-time residents
    - Special circumstances: e.g., caretakers, pregnant, etc.

    Each persona should be unique and realistic.
    """,
    examples=persona_examples,
    suffix=SYNTHETIC_FEW_SHOT_SUFFIX,
    input_variables=["subject", "extra"],
    example_prompt=OPENAI_TEMPLATE,
)

response_prompt_template = FewShotPromptTemplate(
    prefix=SYNTHETIC_FEW_SHOT_PREFIX,
    examples=response_examples,
    suffix=SYNTHETIC_FEW_SHOT_SUFFIX + "\n\nPersona: {persona}\nQuestion: {question}\nGenerate a response:",
    input_variables=["subject", "extra", "persona", "question"],
    example_prompt=OPENAI_TEMPLATE,
)

# Create generators
persona_generator = create_openai_data_generator(
    output_schema=PersonaInformation,
    llm=ChatOpenAI(temperature=0.9),
    prompt=persona_prompt_template,
)

response_generator = create_openai_data_generator(
    output_schema=ResponseData,
    llm=ChatOpenAI(temperature=0.7),
    prompt=response_prompt_template,
)

# %% [markdown]
# ##Persona Generation

# %%
import random

def generate_personas(num_personas: int) -> List[PersonaInformation]:
    communities = list(community_contexts.keys())
    community = communities[0]  # Start with the first community
    context = community_contexts[community]
    community_desc = generate_community_description(community, infrastructure_status[community], context)

    occupations = {
        "Healthcare Worker": 2, "Teacher": 2, "First Responder": 2,
        "Local Government Employee": 2, "Small Business Owner": 2,
        "Factory Worker": 2, "Farmer": 2, "Retired": 2,
        "Unemployed": 2, "Student": 2, "Software Developer": 2,"Lawyer": 2, "Nurse":2,
        "Construction Worker": 2, "Social Worker": 2, "Accountant": 2
    }

    household_compositions = [
        "Single", "Married without children", "Married with young children",
        "Single parent", "Empty nester", "Multigenerational household",
        "Cohabiting partners", "Living with roommates"
    ]

    disaster_experiences = [
        "No major disaster experience",
        "Survived a flood 3 years ago",
        "Experienced a severe hurricane last year",
        "Lived through an earthquake 5 years ago",
        "Dealt with a major wildfire 2 years ago",
        "Multiple experiences with various natural disasters",
        "Volunteered in disaster relief efforts",
        "Lost home in a tornado 4 years ago"
    ]

    socioeconomic_statuses = ["Lower class", "Lower middle class", "Middle class", "Upper middle class", "Upper class"]

    additional_traits = [
        "Recent immigrant", "Long-time community leader", "Person with a physical disability",
        "Caregiver for elderly parent", "LGBTQ+ community member", "Veteran",
        "Climate change activist", "Technology enthusiast", "Local sports coach"
    ]

    # Create a list of occupations based on their weights
    weighted_occupations = [occupation for occupation, weight in occupations.items() for _ in range(weight)]

    extra_prompt = f"""Create {num_personas} unique personas with diverse characteristics including:
    - Ages ranging from 18 to 85+
    - Occupations from this list (some may appear more often): {', '.join(occupations.keys())}
    - Household compositions from this list: {', '.join(household_compositions)}
    - Disaster experiences from this list: {', '.join(disaster_experiences)}
    - Socioeconomic statuses from this list: {', '.join(socioeconomic_statuses)}
    - Additional traits (include one for each persona) from this list: {', '.join(additional_traits)}
    At least one persona should be from {community}. Community description for {community}: {community_desc}.
    Ensure a diverse mix of characteristics across all personas, with a focus on how these characteristics might influence disaster preparedness and response."""

    synthetic_personas = persona_generator.generate(
        subject="storm_scenario_persona",
        extra=extra_prompt,
        runs=num_personas
    )[:num_personas]

    print(f"Generated {len(synthetic_personas)} personas.")

    # Assign communities and IDs to personas
    for i, persona in enumerate(synthetic_personas):
        persona.persona_id = f"P{i+1:03d}"
        if i == 0:
            persona.community = community
            persona.community_description = community_desc
        else:
            assigned_community = communities[i % len(communities)]
            context = community_contexts[assigned_community]
            assigned_community_desc = generate_community_description(assigned_community, infrastructure_status[assigned_community], context)
            persona.community = assigned_community
            persona.community_description = assigned_community_desc

        # Ensure the additional trait is included in the community description
        if "Additional trait:" not in persona.community_description:
            trait = random.choice(additional_traits)
            persona.community_description += f" Additional trait: {trait}."

        # If no occupation is assigned, assign one from the weighted list
        if not hasattr(persona, 'occupation') or not persona.occupation:
            #print("Occupation not assigned:")
            persona.occupation = random.choice(weighted_occupations)

    return synthetic_personas

# Generate personas
num_personas_to_generate = 10
synthetic_personas = generate_personas(num_personas_to_generate)

# Print generated personas
for persona in synthetic_personas:
    print(persona.json(indent=2))
# Out:
# Generated 10 personas.
# {
#   "persona_id": "P001",
#   "community": "Community 1",
#   "age": 35,
#   "occupation": "Teacher",
#   "household_composition": "Married with children",
#   "disaster_experience": "Experienced a flood 5 years ago",
#   "socioeconomic_status": "Middle class",
#   "community_description": "In Community 1: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 5000; - Social vulnerability score: 7/10; - Access to resources: Limited. Additional trait: Technology enthusiast."
# }
# {
#   "persona_id": "P002",
#   "community": "Community 2",
#   "age": 22,
#   "occupation": "Student",
#   "household_composition": "Living with roommates",
#   "disaster_experience": "No major disaster experience",
#   "socioeconomic_status": "Lower class",
#   "community_description": "In Community 2: - Working infrastructure: Power School, Water School, Power House, Water House, Power Commercial; - Damaged infrastructure: Power Residential, Water Residential, Water Commercial; - Population: 12000; - Social vulnerability score: 4/10; - Access to resources: Moderate. Additional trait: Climate change activist."
# }
# {
#   "persona_id": "P003",
#   "community": "Community 3",
#   "age": 27,
#   "occupation": "Healthcare Worker",
#   "household_composition": "Single parent",
#   "disaster_experience": "Experienced a severe hurricane last year",
#   "socioeconomic_status": "Lower middle class",
#   "community_description": "In Community 3: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 20000; - Social vulnerability score: 2/10; - Access to resources: Good. Additional trait: Technology enthusiast."
# }
# {
#   "persona_id": "P004",
#   "community": "Community 1",
#   "age": 35,
#   "occupation": "First Responder",
#   "household_composition": "Married without children",
#   "disaster_experience": "Person with a physical disability",
#   "socioeconomic_status": "Middle class",
#   "community_description": "In Community 1: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 5000; - Social vulnerability score: 7/10; - Access to resources: Limited. Additional trait: LGBTQ+ community member."
# }
# {
#   "persona_id": "P005",
#   "community": "Community 2",
#   "age": 18,
#   "occupation": "Student",
#   "household_composition": "Living with roommates",
#   "disaster_experience": "No major disaster experience",
#   "socioeconomic_status": "Lower class",
#   "community_description": "In Community 2: - Working infrastructure: Power School, Water School, Power House, Water House, Power Commercial; - Damaged infrastructure: Power Residential, Water Residential, Water Commercial; - Population: 12000; - Social vulnerability score: 4/10; - Access to resources: Moderate. Additional trait: Person with a physical disability."
# }
# {
#   "persona_id": "P006",
#   "community": "Community 3",
#   "age": 32,
#   "occupation": "Teacher",
#   "household_composition": "Single",
#   "disaster_experience": "Survived a flood 3 years ago",
#   "socioeconomic_status": "Middle class",
#   "community_description": "In Community 3: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 20000; - Social vulnerability score: 2/10; - Access to resources: Good. Additional trait: Technology enthusiast."
# }
# {
#   "persona_id": "P007",
#   "community": "Community 1",
#   "age": 23,
#   "occupation": "Healthcare Worker",
#   "household_composition": "Single parent",
#   "disaster_experience": "Lived through an earthquake 5 years ago",
#   "socioeconomic_status": "Lower middle class",
#   "community_description": "In Community 1: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 5000; - Social vulnerability score: 7/10; - Access to resources: Limited. Additional trait: Recent immigrant."
# }
# {
#   "persona_id": "P008",
#   "community": "Community 2",
#   "age": 28,
#   "occupation": "Small Business Owner",
#   "household_composition": "Married without children",
#   "disaster_experience": "Experienced a severe hurricane last year",
#   "socioeconomic_status": "Middle class",
#   "community_description": "In Community 2: - Working infrastructure: Power School, Water School, Power House, Water House, Power Commercial; - Damaged infrastructure: Power Residential, Water Residential, Water Commercial; - Population: 12000; - Social vulnerability score: 4/10; - Access to resources: Moderate. Additional trait: Climate change activist."
# }
# {
#   "persona_id": "P009",
#   "community": "Community 3",
#   "age": 18,
#   "occupation": "Student",
#   "household_composition": "Living with roommates",
#   "disaster_experience": "No major disaster experience",
#   "socioeconomic_status": "Lower class",
#   "community_description": "In Community 3: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 20000; - Social vulnerability score: 2/10; - Access to resources: Good. Additional trait: LGBTQ+ community member."
# }
# {
#   "persona_id": "P010",
#   "community": "Community 1",
#   "age": 45,
#   "occupation": "Teacher",
#   "household_composition": "Married with young children",
#   "disaster_experience": "Survived a flood 3 years ago",
#   "socioeconomic_status": "Middle class",
#   "community_description": "In Community 1: - Working infrastructure: Power School, Power House, Water House, Power Commercial, Water Commercial; - Damaged infrastructure: Water School, Power Residential, Water Residential; - Population: 5000; - Social vulnerability score: 7/10; - Access to resources: Limited. Additional trait: LGBTQ+ community member."
# }

# %% [markdown]
# ##Response Generation

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.schema import HumanMessage
import random
from typing import List, Optional
import pandas as pd

# Initialize the language model
llm = ChatOpenAI(temperature=0.7)

RESPONSES_PER_PERSONA = 3

def generate_responses_for_personas(
    personas: List[PersonaInformation],
    questions: List[Question],
    responses_per_persona: int = RESPONSES_PER_PERSONA,
    max_attempts: int = 5
) -> List[dict]:
    responses = []
    response_counter = 1

    for persona in personas:
        print(f"Generating responses for Persona ID: {persona.persona_id}, Occupation: {persona.occupation}")
        selected_questions = random.sample(questions, min(responses_per_persona, len(questions)))

        for question in selected_questions:
            print(f"\nProcessing question: {question.text}")
            valid_response = None
            attempts = 0

            while valid_response is None and attempts < max_attempts:
                try:
                    prompt = PromptTemplate(
                        input_variables=["persona", "question", "option1", "option2", "community_description"],
                        template="""You are a {persona}. Please answer the following question: '{question}'
                        You must choose between '{option1}' and '{option2}'.
                        Provide a detailed reasoning specific to these options and your background.
                        Your response MUST include both a priority choice and a reasoning.

                        Community description: {community_description}

                        Respond in the following format:
                        Priority Choice: [Your chosen option]
                        Reasoning: [Your detailed reasoning]"""
                    )

                    formatted_prompt = prompt.format(
                        persona=f"{persona.occupation} from {persona.community}",
                        question=question.text,
                        option1=question.option1,
                        option2=question.option2,
                        community_description=persona.community_description
                    )

                    response = llm.invoke([HumanMessage(content=formatted_prompt)])

                    # Parse the response
                    response_text = response.content
                    print(f"Response: {response_text}")
                    lines = response_text.split('\n')
                    priority_choice = next((line.split(': ', 1)[1].strip() for line in lines if line.startswith("Priority Choice:")), None)
                    reasoning = next((line.split(': ', 1)[1].strip() for line in lines if line.startswith("Reasoning:")), None)

                    if priority_choice not in [question.option1, question.option2]:
                        print(f"Invalid priority choice: {priority_choice}. Retrying.")
                        attempts += 1
                        continue

                    if not reasoning:
                        print("No reasoning provided. Retrying.")
                        attempts += 1
                        continue

                    ordered_pair = [
                        priority_choice,
                        question.option2 if priority_choice == question.option1 else question.option1
                    ]

                    response_data = ResponseData(
                        response_id=f"R{response_counter:03d}",
                        scenario_id="S001",
                        persona_id=persona.persona_id,
                        question_id=question.question_id,
                        option1=question.option1,
                        option2=question.option2,
                        priority_choice=priority_choice,
                        reasoning=reasoning,
                        ordered_pair=ordered_pair
                    )

                    validation_result, validation_message = validate_response(response_data, persona, question)
                    if validation_result:
                        valid_response = {
                            **response_data.dict(),
                            'community': persona.community,
                            'age': persona.age,
                            'occupation': persona.occupation,
                            'household_composition': persona.household_composition,
                            'disaster_experience': persona.disaster_experience,
                            'socioeconomic_status': persona.socioeconomic_status,
                            'community_description': persona.community_description
                        }
                        responses.append(valid_response)
                        response_counter += 1
                        print("Valid response generated.")
                    else:
                        print(f"Response validation failed: {validation_message}. Retrying...")

                except Exception as e:
                    print(f"Error generating response: {str(e)}")

                attempts += 1

            if valid_response is None:
                print(f"Failed to generate valid response after {max_attempts} attempts")

    return responses

# Generate personas
num_personas_to_generate = 3
print("\n--- Generating Personas ---")
synthetic_personas = generate_personas(num_personas_to_generate)

print("\n--- Summary of Generated Personas ---")
for persona in synthetic_personas:
    print(f"Persona ID: {persona.persona_id}, Occupation: {persona.occupation}, Community: {persona.community}")

# Generate questions
questions = generate_all_possible_questions()

# Generate responses
responses = generate_responses_for_personas(synthetic_personas, questions)

# Create DataFrame for responses (which now include persona information)
responses_df = pd.DataFrame(responses)

# Save to a single CSV file
responses_df.to_csv('personas_and_responses.csv', index=False)
print("\nPersona and Response information has been written to personas_and_responses.csv")

# Print results
print(f"\nGenerated {len(responses)} total responses.")
print(responses_df[['response_id', 'persona_id', 'community', 'occupation', 'priority_choice']])
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Processing question: Which should be repaired first: Power Residential in Community 1 or Water Commercial in Community 2?
# Response: Priority Choice: Repair Water Commercial in Community 2
#
# Reasoning: As a Healthcare Worker from Community 2 with a background in understanding the importance of access to clean water for public health, I believe that repairing the Water Commercial infrastructure in Community 2 should be the priority. Water is essential for sanitation, hygiene, and overall well-being, especially in a community with a population of 12000 people.
#
# The Water Commercial infrastructure serves a larger number of people compared to the Power Residential infrastructure in Community 1. Additionally, given the recent immigrant status of some residents in Community 2, access to clean water is crucial for their settlement and integration into the community. Furthermore, a functioning Water Commercial infrastructure is essential for businesses, schools, and other public spaces in the community.
#
# While repairing the Power Residential infrastructure in Community 1 is important for the residents in that area, ensuring access to clean water for a larger population in Community 2, including recent immigrants, is a more urgent priority for public health and overall community well-being. Repairing the Water Commercial infrastructure will have a more significant impact on the community's overall health and quality of life.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Power Residential in Community 3?
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Healthcare Worker in Community 2, I understand the importance of access to clean water for the health and well-being of a community. Repairing the Water School in Community 1 should be the priority because it directly impacts the education and health of the children in that community. Without access to clean water, the risk of waterborne diseases increases, leading to a potential health crisis. By ensuring that the Water School is repaired, we can provide a safe and healthy learning environment for the children, which will ultimately benefit the overall health of the community. Additionally, addressing this issue aligns with my background in healthcare and my commitment to promoting the well-being of vulnerable populations. Repairing the Water School in Community 1 is not only a matter of education but also a matter of public health, making it the most urgent priority at this time.
# Valid response generated.
# Generating responses for Persona ID: P159, Occupation: Social Worker
#
# Processing question: Which should be repaired first: Water School in Community 1 or Water Residential in Community 3?
# Response: Priority Choice: Repair Water Residential in Community 3
#
# Reasoning: As a Social Worker from Community 3 with a background in climate change activism, my priority is to repair the Water Residential infrastructure in Community 3. While it is important to ensure that all communities have access to clean water, addressing the needs of one's own community should take precedence. The Water Residential infrastructure in Community 3 directly impacts the daily lives and well-being of its 20,000 residents. By prioritizing the repair of this infrastructure, we can ensure that families have access to clean water for drinking, cooking, and sanitation purposes. Additionally, addressing the Water Residential infrastructure in Community 3 aligns with my role as a climate change activist, as access to clean water is essential for both human health and environmental sustainability. Repairing the Water Residential infrastructure in Community 3 will not only improve the quality of life for its residents but also contribute to the overall resilience of the community in the face of climate change challenges.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Power Residential in Community 1?
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Social Worker with a background in advocating for environmental issues, I believe that repairing the Water School in Community 1 should be the priority. Education plays a crucial role in empowering communities to address challenges such as climate change and water conservation. By repairing the Water School, we are not only ensuring that children have access to a safe and conducive learning environment, but we are also investing in the future of the community.
#
# Additionally, access to clean and safe water is a fundamental human right. By repairing the Water School, we are addressing the immediate need for access to clean water for the students and teachers. This will have a positive impact on the health and well-being of the entire community.
#
# While repairing the Power Residential infrastructure is important for the comfort and safety of the residents, I believe that addressing the educational and water needs of the community should take precedence. By prioritizing the repair of the Water School, we are not only promoting education and environmental awareness but also addressing a basic human need.
# Response validation failed: Community Community 3 not mentioned in reasoning. Retrying...
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Social Worker from Community 3 and a climate change activist, I believe that repairing the Water School in Community 1 should be the top priority. Education is essential for the development and well-being of a community, and a functioning school is crucial for the children's learning and future prospects. Additionally, access to clean water is a basic human right, and by repairing the Water School, we can ensure that the children have a safe and healthy environment to learn in. While repairing the Power Residential in Community 1 is important for the residents' daily lives, the immediate impact of repairing the Water School will have a more significant long-term benefit for the community as a whole. By prioritizing education and access to clean water, we can help build a sustainable and thriving community in the long run.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 3 or Power Residential in Community 3?
# Response: Priority Choice: Repair Water School in Community 3
#
# Reasoning: As a Social Worker and climate change activist in Community 3, my priority choice would be to repair the Water School first. Education is essential for the development and well-being of the community's children and future generations. By repairing the Water School, we can ensure that the children have access to a safe and conducive learning environment.
#
# Additionally, addressing the infrastructure issues at the Water School will also have a positive impact on the overall health and hygiene of the community. Access to clean water and sanitation facilities is crucial for preventing diseases and promoting a healthy lifestyle. By repairing the Water School, we can improve the overall quality of life for the residents of Community 3.
#
# While repairing the Power Residential infrastructure is important for the comfort and convenience of the residents, prioritizing the Water School aligns with my values as a climate change activist and social worker. Education and health are fundamental human rights, and by repairing the Water School first, we can make a significant impact on the well-being of the community.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Water School in Community 3?
# Response: Priority Choice: Repair Water School in Community 3
#
# Reasoning: As a Social Worker from Community 3 with a background in climate change activism, my priority choice is to repair the Water School in Community 3. While it is true that both Water Schools in Community 1 and Community 3 are in need of repair, I believe that addressing the infrastructure issues within our own community should be the first step.
#
# Community 3 is home to a population of 20,000 people, many of whom rely on the Water School for access to clean and safe drinking water. By repairing the Water School in our own community, we can ensure that our residents have continued access to this essential resource. Additionally, as a climate change activist, I recognize the importance of promoting sustainability and resilience within our community infrastructure. By prioritizing the repair of the Water School in Community 3, we can work towards creating a more sustainable and climate-resilient water system for our residents.
#
# While it is important to support our neighboring communities, I believe that addressing the needs of our own community should be our first priority. Once the Water School in Community 3 has been repaired and our residents have access to clean water, we can then turn our attention to supporting the repair of the Water School in Community 1. Ultimately, by focusing on our own community first, we can ensure the well-being and resilience of our residents in the face of climate change and other challenges.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Residential in Community 1 or Power Residential in Community 2?
# Response: Priority Choice: Repair Water Residential in Community 1
#
# Reasoning: As a Social Worker from Community 3 and as a climate change activist, I believe that repairing Water Residential in Community 1 should be the top priority. Access to clean and safe water is a basic human right and essential for the health and well-being of residents. Without functioning water infrastructure, the community may face serious health risks such as waterborne diseases and lack of proper sanitation.
#
# Furthermore, addressing the water issue in Community 1 aligns with my background as a social worker and climate change activist. Water scarcity and quality are increasingly becoming critical issues due to climate change, and it is crucial to ensure that communities have access to sustainable and reliable water sources.
#
# While power is also important for daily living, the immediate impact of not having access to water is far more severe. By prioritizing the repair of Water Residential in Community 1, we can ensure the health and safety of the residents while also addressing the long-term implications of climate change on water resources.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Water Residential in Community 1?
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Social Worker and Climate Change Activist, my priority choice would be to repair the Water School in Community 1. Education is essential for the development and well-being of a community, and ensuring that children have access to a safe and functioning learning environment is crucial. By repairing the Water School, we can provide a conducive space for children to receive education, which in turn can empower them to make positive changes in their community. Additionally, investing in education can have long-term benefits for the overall growth and sustainability of the community. Repairing the Water Residential can also be important, but in this case, prioritizing the Water School aligns with my values and advocacy for education and social development.
# Response validation failed: Community Community 3 not mentioned in reasoning. Retrying...
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Social Worker with a background in climate change activism, I believe that education is a key factor in addressing environmental issues. By repairing the Water School in Community 1, we can ensure that the next generation is equipped with the knowledge and skills to tackle water-related challenges effectively. Additionally, a functional Water School will benefit not only the students but also the wider community by raising awareness and promoting sustainable water practices. While repairing the Water Residential infrastructure is important for the well-being of the residents, prioritizing the Water School will have a more significant and long-lasting impact on the community's overall resilience and ability to adapt to changing environmental conditions. Therefore, I recommend repairing the Water School in Community 1 as the first priority.
# Response validation failed: Community Community 3 not mentioned in reasoning. Retrying...
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Social Worker with a background in climate change activism, my priority would be to repair the Water School in Community 1. Education is crucial for the development and well-being of a community, and a functioning school with access to clean water is essential for the children in Community 1. By repairing the Water School, we can ensure that the students have a safe and healthy learning environment, which will ultimately benefit the entire community in the long run. Additionally, addressing the needs of the school first can help prevent further issues related to education and health in Community 1. Once the Water School is repaired, we can then focus on addressing the water residential issues in the community.
# Response validation failed: Community Community 3 not mentioned in reasoning. Retrying...
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Social Worker and Climate Change Activist, my priority choice would be to repair the Water School in Community 1 first. Education is a fundamental right for all individuals, and ensuring that the students in Community 1 have access to clean water at their school is crucial for their health and well-being. Additionally, by repairing the Water School, we are investing in the future of the community by providing a safe and conducive learning environment for the next generation.
#
# While access to clean water in residential areas is also important, the Water School serves a larger population of students who rely on this resource for their daily needs. By addressing the water issue at the school, we can have a positive impact on the health and academic performance of the students, ultimately benefiting the entire community in the long run.
#
# Furthermore, repairing the Water School aligns with my background as a Climate Change Activist, as education plays a key role in raising awareness and promoting sustainable practices to combat environmental challenges. By prioritizing the repair of the Water School, we are not only addressing the immediate need for clean water but also fostering a culture of environmental stewardship and resilience within the community.
# Response validation failed: Community Community 3 not mentioned in reasoning. Retrying...
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Social Worker and a Climate Change Activist, my priority is to ensure that the basic needs of the community are met in a sustainable and equitable manner. In this case, repairing the Water School in Community 1 should be the first priority. Education is a fundamental right for children, and having access to clean water at school is crucial for their health and well-being. By repairing the Water School, we are not only providing a safe and healthy learning environment for the children in Community 1 but also promoting the importance of water conservation and sustainability.
#
# While access to clean water in residential areas is also important, prioritizing the repair of the Water School will have a broader impact on the community as a whole. Children are the future leaders and advocates for environmental protection, and by ensuring they have access to clean water at school, we are instilling in them the values of conservation and sustainability. Additionally, repairing the Water School can serve as a model for other schools in the community to follow, further spreading awareness and promoting responsible water usage.
#
# In conclusion, repairing the Water School in Community 1 aligns with my values as a Social Worker and Climate Change Activist, and it has the potential to create a positive ripple effect in the community by educating and empowering the next generation.
# Response validation failed: Community Community 3 not mentioned in reasoning. Retrying...
# Failed to generate valid response after 5 attempts
#
# Processing question: Which should be repaired first: Power Residential in Community 2 or Water Commercial in Community 2?
# Response: Priority Choice: Repair Power Residential in Community 2
#
# Reasoning: As a Social Worker from Community 3, my background in advocating for climate change awareness and social vulnerability informs my decision to prioritize repairing Power Residential in Community 2. Power is essential for heating, cooling, and powering electronic devices, which are crucial for daily living in residential areas. By addressing the power outage in the residential sector, we can ensure the safety and well-being of the individuals living in Community 2, especially in times of extreme weather conditions caused by climate change. Additionally, a lack of power can impact access to communication, healthcare, and other essential services for the residents.
#
# While water is also essential for commercial activities in Community 2, the immediate priority should be to address the power outage in the residential sector to prevent further social vulnerability and ensure the overall well-being of the residents. Once the power issue is resolved, efforts can be directed towards repairing the water infrastructure in the commercial sector to support economic activities and community development.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 1 or Water Residential in Community 2?
# Response: Priority Choice: Repair Water Residential in Community 2
#
# Reasoning: As a social worker with a background in advocating for environmental issues, I believe that access to clean water is a fundamental human right that should be prioritized. While access to power is important for daily living, water is essential for basic hygiene, health, and overall quality of life. Without clean water in Community 2, residents are at risk of waterborne diseases and other health issues. By repairing the Water Residential infrastructure in Community 2, we can ensure that residents have safe and reliable access to clean water for drinking, cooking, and sanitation. Additionally, addressing the water infrastructure in Community 2 aligns with my values as a climate change activist, as ensuring access to clean water is crucial in building resilient and sustainable communities. Repairing the Water Residential infrastructure in Community 2 will have a more immediate and significant impact on the well-being of residents, making it the top priority in this situation.
# Response validation failed: Community Community 3 not mentioned in reasoning. Retrying...
# Response: Priority Choice: Repair Power Residential in Community 1
#
# Reasoning: As a Social Worker from Community 3 and a climate change activist, I believe that repairing Power Residential in Community 1 should be the priority. While both power and water are essential for daily living, the power infrastructure being damaged in Community 1 could potentially lead to more severe consequences. Without power, residents may not have access to heating, cooling, and essential electronic devices. This could result in health and safety risks, especially during extreme weather conditions.
#
# Additionally, as a climate change activist, I understand the importance of sustainable energy sources. By repairing the power infrastructure in Community 1, we can potentially explore renewable energy options and reduce the community's reliance on fossil fuels. This aligns with my values and goals as an advocate for environmental sustainability.
#
# While access to clean water is crucial, the social vulnerability score of Community 3 is relatively low, indicating that residents have good access to resources. This suggests that they may have alternative sources of water available to them while the repairs are being carried out.
#
# In conclusion, repairing Power Residential in Community 1 not only addresses immediate safety concerns but also aligns with long-term sustainability goals.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 2 or Water Residential in Community 2?
# Response: Priority Choice: Repair Water Residential in Community 2
#
# Reasoning: As a Social Worker and Climate Change activist, I understand the importance of water access and how crucial it is for the well-being of a community. While having access to power is also essential for daily activities, water is a basic necessity for human survival. Repairing the Water Residential infrastructure in Community 2 should be the top priority as it directly impacts the health and quality of life of the residents. Without access to clean water for drinking, cooking, and sanitation, the community members are at risk of various health issues and waterborne diseases. Additionally, water is crucial for agricultural activities and overall community development.
#
# Furthermore, considering the social vulnerability score of the community is relatively low at 2/10 and access to resources is good, it is more feasible to prioritize repairing the Water Residential infrastructure. Once the water issue is addressed, the community can focus on repairing the Power Residential infrastructure to ensure a well-rounded and sustainable living environment for all residents.
# Response validation failed: Community Community 3 not mentioned in reasoning. Retrying...
# Response: Priority Choice: Repair Water Residential in Community 2
#
# Reasoning: As a Social Worker who is also a climate change activist, I understand the importance of access to clean and safe water for the well-being of the community. While access to power is crucial for many aspects of daily life, such as heating, cooling, and electronic devices, water is essential for survival. Without functioning water infrastructure, the residents of Community 2 would be unable to meet their basic needs, maintain hygiene, and prevent the spread of diseases. Furthermore, in the face of climate change, access to clean water becomes even more critical as extreme weather events can disrupt water supply systems.
#
# Repairing the Water Residential infrastructure in Community 2 should be the top priority to ensure the health and safety of the residents. Once this essential need is met, efforts can be directed towards repairing the Power Residential infrastructure to improve overall quality of life in the community. By prioritizing the repair of water infrastructure, we can address the most urgent need and lay the foundation for a more sustainable and resilient community in the face of climate change.
# Response validation failed: Community Community 3 not mentioned in reasoning. Retrying...
# Response: Priority Choice: Repair Water Residential in Community 2
#
# Reasoning: As a Social Worker with a background in climate change activism, I understand the importance of water as a vital resource for life. Repairing the Water Residential infrastructure in Community 2 should be the top priority because access to clean and safe water is essential for the health and well-being of the community members. Without access to clean water, residents are at risk of waterborne diseases and other health issues. Additionally, water is necessary for proper sanitation, hygiene, and overall quality of life.
#
# While having electricity is important for various aspects of daily life, such as powering appliances and lights, the lack of access to clean water poses a more immediate threat to the community's health and safety. By prioritizing the repair of the Water Residential infrastructure in Community 2, we can ensure that residents have access to this basic necessity and prevent potential health crises. Once the water infrastructure is repaired, we can then focus on addressing the power issues in the community to improve overall living conditions.
# Response validation failed: Community Community 3 not mentioned in reasoning. Retrying...
# Response: Priority Choice: Repair Water Residential in Community 2
#
# Reasoning: As a Social Worker and climate change activist, I believe it is crucial to prioritize repairing the Water Residential infrastructure in Community 2. Access to clean water is a basic human right and essential for the health and well-being of the residents. Without functioning water infrastructure, the community may face serious health risks such as waterborne diseases and sanitation issues.
#
# While Power Residential is also important for daily living, the immediate concern should be ensuring access to clean water for the residents. Water is necessary for cooking, cleaning, drinking, and sanitation purposes. By addressing the water infrastructure first, we can prevent potential health crises and ensure the overall well-being of the community members.
#
# Furthermore, with a social vulnerability score of 2/10 in Community 3, it is essential to prioritize the repair of basic needs such as water access. By repairing the Water Residential infrastructure, we can support the community's resilience and ability to thrive despite any challenges they may face. Ultimately, by focusing on repairing the water system first, we can promote a healthier and more sustainable community for all residents.
# Response validation failed: Community Community 3 not mentioned in reasoning. Retrying...
# Response: Priority Choice: Repair Water Residential in Community 2
#
# Reasoning: As a Social Worker and climate change activist, my priority is to ensure access to clean and safe water for the residents of Community 2. Water is essential for human survival and well-being, and the lack of access to clean water can lead to various health issues and overall decrease in quality of life. By repairing the Water Residential infrastructure in Community 2, we can ensure that residents have access to clean water for drinking, cooking, and sanitation purposes.
#
# While access to power is also important for various aspects of daily life, such as lighting and heating, water is a more immediate and critical need. Without safe water, the health and well-being of the community members in Community 2 will be at risk. Therefore, I believe that repairing the Water Residential infrastructure should be given priority in order to address this fundamental need of the residents. Additionally, by prioritizing water infrastructure repair, we can also contribute to the overall resilience of the community in the face of climate change and other future challenges.
# Response validation failed: Community Community 3 not mentioned in reasoning. Retrying...
# Failed to generate valid response after 5 attempts
#
# Processing question: Which should be repaired first: Water Residential in Community 2 or Water Commercial in Community 2?
# Response: Priority Choice: Repair Water Residential in Community 2
#
# Reasoning: As a Social Worker and climate change activist, my priority choice is to repair Water Residential in Community 2. Access to clean water is a basic human right and essential for the health and well-being of individuals and families. By prioritizing the repair of Water Residential infrastructure in Community 2, we are ensuring that residents have access to safe and clean water for drinking, cooking, and sanitation purposes.
#
# While Water Commercial is important for businesses and economic activities, the immediate need for clean water in residential areas cannot be overlooked. Without access to clean water, residents may face serious health risks and challenges in their daily lives. By addressing the repair of Water Residential infrastructure first, we are prioritizing the well-being and safety of the community members.
#
# Additionally, by addressing the repair of Water Residential infrastructure, we are also indirectly supporting the economic activities in the community. Businesses rely on a healthy and productive workforce, which can only be achieved if residents have access to clean water. Therefore, repairing Water Residential in Community 2 not only addresses a basic human need but also contributes to the overall well-being and sustainability of the community.
# Response validation failed: Community Community 3 not mentioned in reasoning. Retrying...
# Response: Priority Choice: Repair Water Residential in Community 2
#
# Reasoning: As a Social Worker and Climate Change activist, I believe that repairing Water Residential in Community 2 should be the priority. Access to clean and safe drinking water is a basic human right, and repairing the water infrastructure in residential areas is crucial for the health and well-being of the community members. Without proper access to clean water, residents are at risk of waterborne diseases and other health issues.
#
# Additionally, ensuring that residential areas have access to water is essential for maintaining hygiene, sanitation, and overall quality of life. By prioritizing the repair of Water Residential in Community 2, we can address the immediate needs of the residents and mitigate any potential health risks associated with the lack of clean water.
#
# While Water Commercial is also important for economic activities in the community, the health and well-being of the residents should take precedence. Once the residential water infrastructure is repaired, we can then shift our focus to repairing the water infrastructure in commercial areas to support economic growth and development in the community.
# Response validation failed: Community Community 3 not mentioned in reasoning. Retrying...
# Response: Priority Choice: Repair Water Residential in Community 2
#
# Reasoning: As a Social Worker from Community 3, my priority is the well-being of the residents in Community 2. Access to clean and safe water is a basic human right and essential for maintaining health and hygiene. By repairing the water residential infrastructure in Community 2, we can ensure that families have access to clean water for drinking, cooking, and sanitation purposes. This will directly improve the quality of life for the residents who rely on this infrastructure on a daily basis.
#
# While water commercial infrastructure is important for economic activities and businesses in the community, the immediate need for clean water for residential purposes outweighs the commercial aspect. Additionally, addressing the water residential infrastructure first can help prevent potential health hazards and waterborne diseases that may arise from lack of access to clean water.
#
# Furthermore, as a climate change activist, I understand the importance of sustainable and equitable access to resources. Repairing the water residential infrastructure aligns with my values of promoting social and environmental justice by ensuring that all community members have access to essential resources for their well-being. Therefore, I believe that repairing the water residential infrastructure in Community 2 should be prioritized.
# Valid response generated.
# Generating responses for Persona ID: P160, Occupation: Social Worker
#
# Processing question: Which should be repaired first: Water Residential in Community 1 or Water Commercial in Community 2?
# Response: Priority Choice: Repair Water Residential in Community 1
#
# Reasoning: As a Social Worker from Community 1, my primary concern is the well-being and safety of the residents in my own community. With a population of 5000 and a social vulnerability score of 7/10, it is crucial to prioritize the repair of Water Residential in Community 1. This infrastructure directly impacts the daily lives of the residents, as access to clean and safe water is essential for their health, hygiene, and overall quality of life. Without functioning water residential facilities, the residents are forced to rely on limited resources or travel long distances to access water for their basic needs.
#
# Furthermore, addressing the repair of Water Residential in Community 1 aligns with my role as a Social Worker to advocate for the needs of the community members and promote their well-being. By prioritizing the repair of Water Residential, we can ensure that the residents have access to a basic necessity and improve their overall living conditions. Once the immediate needs of the residents in Community 1 are addressed, we can then work towards addressing the water commercial infrastructure in Community 2 to support economic activities and development in that area.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Residential in Community 1 or Power Residential in Community 2?
# Response: Priority Choice: Repair Water Residential in Community 1
#
# Reasoning: As a Social Worker from Community 1, it is crucial to prioritize the repair of Water Residential infrastructure within our own community before addressing issues in Community 2. Access to clean water is a basic human need and the lack of functioning water infrastructure in the residential areas of our community poses a serious health and safety risk to our residents. Without access to clean water for drinking, cooking, and sanitation, the well-being of our community members is at stake.
#
# Furthermore, considering the social vulnerability score of Community 1 is 7/10 and the limited access to resources, it is essential to focus on addressing the needs of our own community first before extending assistance to others. By repairing the Water Residential infrastructure in Community 1, we can ensure that our residents have access to a basic necessity that is crucial for their health and quality of life.
#
# Additionally, as a Social Worker with knowledge of the local sports coach in our community, collaboration and community engagement can be facilitated to address this issue effectively. By working together with community members, local leaders, and resources, we can prioritize the repair of Water Residential infrastructure in Community 1 and ensure the well-being of our residents.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Residential in Community 1 or Water School in Community 3?
# Response: Priority Choice: Repair Water Residential in Community 1
#
# Reasoning: As a Social Worker in Community 1, my priority would be to repair the Water Residential infrastructure in this community first. This is because access to clean and safe water is a basic human need and essential for the health and well-being of the residents. Without proper water infrastructure in the residential areas, the 5000 inhabitants of Community 1 are at risk of waterborne diseases and other health issues.
#
# Additionally, considering the social vulnerability score of 7/10 in Community 1, it is crucial to prioritize the repair of the Water Residential infrastructure to ensure the most vulnerable members of the community have access to clean water. By addressing this issue first, we can improve the overall quality of life for the residents and prevent potential health crises.
#
# Although repairing the Water School in Community 3 is also important, the immediate priority should be on addressing the needs of the residents in Community 1 who are currently lacking access to clean water in their homes. Once the Water Residential infrastructure is repaired and functioning properly, efforts can be directed towards repairing the Water School in Community 3 to ensure all members of both communities have access to safe water.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 2 or Water Commercial in Community 2?
# Response: Priority Choice: Repair Power Residential in Community 2
#
# Reasoning: As a Social Worker coming from Community 1 with a background in working with vulnerable populations, I believe that repairing Power Residential in Community 2 should be the priority. Power is essential for heating, cooling, and providing electricity for households. Without power, residents may face health and safety risks, especially in extreme weather conditions. Additionally, power is crucial for communication and access to information, which is essential for the well-being of the community.
#
# While access to water is also important, the commercial sector in Community 2 may have alternative resources or means of obtaining water temporarily. In contrast, the residential sector is where families live and where the most vulnerable members of the community, such as children and the elderly, are located. Therefore, by prioritizing the repair of Power Residential, we can ensure the safety and well-being of the community members in Community 2.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Commercial in Community 2 or Water School in Community 3?
# Response: Priority Choice: Repair Water School in Community 3
#
# Reasoning: As a Social Worker with a background in community development, I believe that repairing the Water School in Community 3 should be the top priority. Education is essential for the future well-being and success of the community's children. Without access to clean water at the school, students are at risk of falling ill and missing out on valuable learning opportunities. By repairing the Water School, we can ensure that the students have a safe and healthy environment to learn and thrive in.
#
# While having access to clean water in commercial areas is important for economic activities, the immediate impact on the education and well-being of children in the Water School is more pressing. By prioritizing the repair of the Water School, we can support the future generation of Community 3 and contribute to their overall development and success. Additionally, investing in education can have long-term positive effects on the community as a whole.
#
# In conclusion, repairing the Water School in Community 3 should be the first step in addressing the infrastructure needs of the community, considering the importance of education and the well-being of its residents.
# Response validation failed: Community Community 1 not mentioned in reasoning. Retrying...
# Response: Priority Choice: Repair Water School in Community 3
#
# Reasoning: As a Social Worker from Community 1, it is essential to prioritize the repair of the Water School in Community 3 over the Water Commercial in Community 2. The education of children in Community 3 is of utmost importance as it directly impacts their future opportunities and overall well-being. Without access to clean water at the school, students are at risk of illness and may struggle to focus on their studies. By repairing the water infrastructure at the school, we can ensure that the children have a safe and healthy learning environment.
#
# Additionally, addressing the needs of the school will benefit the entire community by promoting education and empowering the younger generation. Education is a key factor in breaking the cycle of poverty and improving social outcomes. While the Water Commercial in Community 2 is important for economic activities, the immediate focus should be on ensuring that the children in Community 3 have access to clean water at their school.
#
# Furthermore, by prioritizing the repair of the Water School in Community 3, we can demonstrate our commitment to investing in the well-being and future of our communities. It is crucial to support the education of our youth and provide them with the necessary resources to thrive. Repairing the water infrastructure at the school is a vital step towards creating a more sustainable and equitable society.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Commercial in Community 2 or Power Residential in Community 3?
# Response: Priority Choice: Repair Water Commercial in Community 2
#
# Reasoning: As a Social Worker from Community 1, my priority choice would be to repair Water Commercial in Community 2. This decision is based on the fact that water is a basic necessity for human survival and the lack of access to clean water can have severe health consequences for the residents of Community 2. Without a functioning water commercial infrastructure, the residents may resort to using contaminated water sources which can lead to waterborne diseases and further exacerbate the social vulnerability of the community.
#
# Repairing the Water Commercial in Community 2 will not only address the immediate health needs of the residents but also contribute to improving overall community well-being. Additionally, access to clean water is essential for sanitation, hygiene, and overall quality of life. By repairing the water commercial infrastructure, we can help prevent potential health crises and promote a healthier environment for the residents of Community 2.
#
# While repairing Power Residential in Community 3 is also important for ensuring access to electricity for the residents, addressing the lack of clean water in Community 2 takes precedence due to the immediate health risks associated with contaminated water sources. As a Social Worker, my primary concern is the well-being of the community members, and repairing the water commercial infrastructure in Community 2 aligns with this goal.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Residential in Community 1 or Water Residential in Community 3?
# Response: Priority Choice: Repair Water Residential in Community 1
#
# Reasoning: As a Social Worker from Community 1, my priority is to address the needs of my own community first. Repairing the Water Residential infrastructure in Community 1 is crucial for the health and well-being of the residents, as access to clean water is a basic human right. With a population of 5000 and a social vulnerability score of 7/10, it is evident that the residents of Community 1 are in need of immediate assistance. Additionally, the limited access to resources in Community 1 makes it even more imperative to prioritize the repair of the Water Residential infrastructure in order to ensure the safety and quality of life for the residents. Furthermore, with the presence of a local sports coach in the community, there is potential for community engagement and mobilization to address this issue effectively. Repairing the Water Residential infrastructure in Community 1 will not only benefit the residents directly but also contribute to the overall well-being and resilience of the community.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Residential in Community 1 or Power Residential in Community 3?
# Response: Priority Choice: Repair Water Residential in Community 1
#
# Reasoning: As a Social Worker from Community 1, I believe that repairing the Water Residential infrastructure in our own community should be the top priority. Water is a basic necessity for life, and the lack of access to clean water can lead to various health issues, especially for a population of 5000 people with limited access to resources and a high social vulnerability score of 7/10. By fixing the Water Residential infrastructure, we can ensure that the residents have access to clean water for drinking, cooking, and sanitation purposes.
#
# Additionally, by prioritizing the repair of Water Residential infrastructure in our own community, we can set an example for other communities and show that the well-being of our residents is a top priority. It is important to take care of our own community first before assisting others, especially when the need is urgent.
#
# While repairing the Power Residential infrastructure in Community 3 is also important, I believe that addressing the basic need for clean water in our own community should take precedence. Once the Water Residential infrastructure is repaired in Community 1, we can then work towards assisting Community 3 with their power issues.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 3 or Water Residential in Community 3?
# Response: Priority Choice: Repair Water School in Community 3
#
# Reasoning: As a Social Worker from Community 1 with a background in working with vulnerable populations, I believe that repairing the Water School in Community 3 should be the top priority. Education is essential for the development and well-being of individuals, especially children. By repairing the Water School, we can ensure that the students have access to clean water and a safe learning environment. This will not only benefit the current students but also future generations in the community.
#
# Additionally, a functioning Water School can serve as a hub for the community, providing resources and support for families. It can also help in improving the overall social vulnerability score of the community by increasing access to education and opportunities for the residents.
#
# While repairing Water Residential in Community 3 is important for the well-being of the residents, prioritizing the Water School will have a broader impact on the community as a whole. By investing in education, we can create a foundation for sustainable development and empower individuals to break the cycle of poverty and vulnerability.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Water Residential in Community 3?
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Social Worker from Community 1, my priority choice would be to repair the Water School in our own community before focusing on the Water Residential in Community 3. The Water School serves as a critical resource for the education and well-being of the children in our community. Without access to clean water at the school, students may face health risks and challenges in their learning environment. Education is key to breaking the cycle of poverty and improving the overall well-being of our community members. Additionally, a functioning Water School can also serve as a safe space for children to access clean water, which can have a positive impact on their health and development.
#
# Furthermore, by investing in repairing the Water School in Community 1, we are prioritizing the needs of our own community members who may already be facing social vulnerability. It is important to address the immediate needs of those within our own community before extending our resources to other communities. Additionally, with limited access to resources, it may be more feasible to address the repairs needed in our own community first.
#
# Overall, repairing the Water School in Community 1 aligns with our goal of promoting education, health, and well-being within our community, and it is crucial to prioritize the needs of our own community members before extending support to others.
# Valid response generated.
# Generating responses for Persona ID: P161, Occupation: Teacher
#
# Processing question: Which should be repaired first: Water School in Community 1 or Water Residential in Community 2?
# Response: Priority Choice: Repair Water School in Community 1
#
# ...
# Valid response generated.
# Generating responses for Persona ID: P200, Occupation: Teacher
#
# Processing question: Which should be repaired first: Power Residential in Community 1 or Water Residential in Community 1?
# Response: Priority Choice: Repair Water Residential in Community 1
#
# Reasoning: As a Teacher from Community 2 with a background in education and a focus on community well-being, I believe that repairing Water Residential in Community 1 should be the priority. Water is a fundamental necessity for human life and is essential for maintaining health and sanitation standards. Without access to clean water, the residents of Community 1 are at risk of waterborne diseases and overall reduced quality of life.
#
# Additionally, considering the social vulnerability score of 4/10 in Community 2 and the fact that there are recent immigrants in the community, it is crucial to prioritize the repair of Water Residential infrastructure. This will not only ensure the health and well-being of the residents but also contribute to their overall integration and stability in the community.
#
# While Power Residential is also important for daily living, water is a more immediate and critical need. By repairing Water Residential first, we can address the most pressing issue and work towards creating a healthier and more sustainable environment for the residents of Community 1.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Power Residential in Community 3?
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Teacher in Community 2 with a background in education, I believe that repairing the Water School in Community 1 should be the first priority. The education of children is crucial for the development and future success of a community. By ensuring that the Water School is functioning properly, we can provide a safe and conducive learning environment for the students in Community 1. Additionally, access to clean water is essential for the health and well-being of the students and staff at the school.
#
# While repairing the Power Residential in Community 3 is important for the overall infrastructure of the community, the immediate impact on the lives of residents may not be as significant as ensuring that the children in Community 1 have access to a functioning school. Education plays a vital role in breaking the cycle of poverty and empowering individuals to improve their quality of life. By prioritizing the repair of the Water School in Community 1, we can make a positive impact on the future of the community as a whole.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 2 or Power Residential in Community 3?
# Response: Priority Choice: Repair Power Residential in Community 2
#
# Reasoning: As a teacher in Community 2, I have seen first-hand the impact of the damaged infrastructure on the residents. Power Residential in Community 2 is essential for providing electricity to the homes of the 12000 residents, including families with children who attend the schools where I teach. Without power in their homes, students may struggle to complete homework assignments, parents may have difficulty preparing meals, and overall quality of life may be diminished.
#
# Additionally, considering the social vulnerability score of 4/10 and the recent immigrant status of many residents in Community 2, it is crucial to prioritize repairing Power Residential in order to ensure that these vulnerable populations have access to basic necessities. By addressing the power outage in Community 2, we can help improve the overall well-being and resilience of the community.
#
# While it is important to address infrastructure issues in both communities, repairing Power Residential in Community 2 should take precedence due to the immediate impact it will have on the residents and their daily lives.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Residential in Community 1 or Power Residential in Community 3?
# Response: Priority Choice: Repair Power Residential in Community 3
#
# Reasoning: As a Teacher from Community 2 with a background in education and community development, I believe that repairing the Power Residential infrastructure in Community 3 should be prioritized. While access to clean water is essential for daily living, the lack of power in residential areas can have a more immediate impact on the well-being and safety of individuals, especially during extreme weather conditions or emergencies. Without power, residents may not have access to heating or cooling, lighting, or the ability to charge essential devices such as phones for communication.
#
# Additionally, restoring power in residential areas can help improve the overall quality of life for the community by enabling residents to carry out daily activities, such as cooking, studying, and working from home. This is particularly important for the recent immigrant population who may already be facing challenges in adjusting to a new environment.
#
# While repairing the water infrastructure is crucial, the immediate impact and potential risks associated with a lack of power in residential areas make it a higher priority in this scenario. Once the power infrastructure is restored in Community 3, efforts can then be focused on repairing the water infrastructure in Community 1 to ensure access to clean water for all residents.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Water Residential in Community 1?
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a Teacher from Community 2 with a background in education, I believe that repairing the Water School in Community 1 should be the first priority. Education plays a crucial role in the development and well-being of a community, especially for the children who are the future of society. Without access to clean water at the school, students may face health risks and be unable to concentrate on their studies. By repairing the Water School first, we can ensure a safe and healthy learning environment for the students, which will ultimately benefit the entire community in the long run. Additionally, addressing the water issue at the school may also have a positive ripple effect on the surrounding residential area, as students can bring home knowledge about water hygiene and conservation practices. Overall, prioritizing the repair of the Water School aligns with my expertise and values as an educator, and I believe it will have the greatest impact on the community as a whole.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 2 or Water Commercial in Community 2?
# Response: Priority Choice: Repair Water Commercial in Community 2
#
# Reasoning: As a teacher in Community 2, my priority choice would be to repair Water Commercial infrastructure first. Water is essential not only for residential use but also for commercial activities in the community. Without access to clean water in commercial areas, businesses may struggle to operate effectively and provide essential goods and services to the residents. This could have a significant impact on the overall economy of the community and the livelihoods of its residents. Additionally, repairing the Water Commercial infrastructure would also benefit the residential areas by ensuring a stable water supply for households.
#
# While repairing the Power Residential infrastructure is important for ensuring the comfort and safety of residents, addressing the Water Commercial infrastructure first can have a more immediate and widespread positive impact on the community as a whole. As a teacher working closely with families and children in the community, I understand the importance of access to clean water for health, sanitation, and overall well-being. Therefore, prioritizing the repair of Water Commercial infrastructure would help to improve the quality of life for all residents in Community 2, including the recent immigrants who may be particularly vulnerable to water-related challenges.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water School in Community 1 or Water School in Community 3?
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a recent immigrant in Community 2, I understand the importance of education and the impact it has on the overall development and well-being of a community. Repairing the Water School in Community 1 should be the priority because education is the foundation for a better future for the residents. By ensuring that the Water School in Community 1 is repaired, we are providing the children with a safe and conducive learning environment, which will ultimately contribute to the overall growth and prosperity of the community. Additionally, investing in education can help break the cycle of poverty and social vulnerability, leading to a more sustainable and resilient community in the long run. Repairing the Water School in Community 1 will not only benefit the current residents but also future generations, making it a crucial priority for the overall well-being of the community.
# Response validation failed: Occupation Teacher not mentioned in reasoning. Retrying...
# Response: Priority Choice: Repair Water School in Community 1
#
# Reasoning: As a teacher from Community 2 and a recent immigrant, I understand the importance of education in building a strong foundation for the future of a community. Repairing the Water School in Community 1 should be the priority because education is essential for the development and well-being of the residents. Without a functioning school, the children in Community 1 will be deprived of the opportunity to learn and grow, which can have long-lasting negative effects on their lives.
#
# Additionally, by prioritizing the repair of the Water School in Community 1, we can ensure that the next generation has access to quality education, which can help break the cycle of poverty and vulnerability in the community. While the Water School in Community 3 is also important, addressing the immediate needs of the children in Community 1 should take precedence to secure a brighter future for the entire community.
#
# In conclusion, repairing the Water School in Community 1 is the best choice to make a positive impact on the lives of the residents and set the foundation for a thriving community.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Residential in Community 1 or Water Residential in Community 2?
# Response: Priority Choice: Repair Water Residential in Community 2
# Reasoning: As a Teacher in Community 2, my priority would be to repair the Water Residential infrastructure within our own community. Although there is also a need to repair the Water Residential in Community 1, my responsibility lies with the well-being and safety of the residents in my own community first. With a population of 12000 and a social vulnerability score of 4/10, it is crucial to ensure that the residents have access to clean and safe water for their daily needs. Additionally, being a recent immigrant community, there may be language barriers and limited access to resources, making it even more essential to address the water infrastructure within Community 2 promptly. By repairing the Water Residential infrastructure in our own community, we can improve the quality of life for our residents and ensure their basic needs are met.
# Valid response generated.
#
# Processing question: Which should be repaired first: Water Residential in Community 1 or Water Commercial in Community 2?
# Response: Priority Choice: Repair Water Commercial in Community 2
#
# Reasoning: As a teacher in Community 2, it is important to prioritize the repair of Water Commercial infrastructure over Water Residential in Community 1. The Water Commercial infrastructure serves the businesses and industries in the community, which are crucial for economic stability and growth. Without access to clean water, these businesses will suffer, leading to potential job losses and economic downturn. This can have a ripple effect on the entire community, impacting the livelihoods of the residents, including the students and families I work with.
#
# Additionally, the population of Community 2 is relatively large at 12000, and the social vulnerability score is 4/10, indicating that the residents may already be facing challenges. By prioritizing the repair of Water Commercial infrastructure, we can help support the local economy and potentially improve the overall quality of life for the community members. As a recent immigrant myself, I understand the importance of economic stability and access to resources for newcomers trying to establish themselves in a new community.
#
# While repairing Water Residential in Community 1 is important, addressing the needs of the businesses and industries in Community 2 first will have a more immediate and widespread positive impact on the community as a whole.
# Valid response generated.
#
# Processing question: Which should be repaired first: Power Residential in Community 1 or Power Residential in Community 3?
# Response: Priority Choice: Repair Power Residential in Community 1
#
# Reasoning: As a teacher from Community 2 with a background in education and a focus on the well-being of our residents, I believe repairing Power Residential in Community 1 should be the priority. This choice is based on the fact that Community 1 is likely facing significant challenges due to the lack of power in their residential area. Without power, residents may be experiencing difficulties in daily tasks such as cooking, heating, and accessing communication devices. This can have a direct impact on their quality of life and overall well-being.
#
# Additionally, repairing Power Residential in Community 1 may also have a positive ripple effect on the rest of the community. By addressing the needs of Community 1 first, we can potentially prevent further issues from arising and ensure a more stable environment for all residents in both Community 1 and Community 2. As a recent immigrant myself, I understand the importance of community support and solidarity, and believe that by prioritizing the repair of Power Residential in Community 1, we can demonstrate our commitment to helping those in need and fostering a sense of unity among all residents.
# Valid response generated.
#
# Persona and Response information has been written to personas_and_responses.csv
#
# Generated 1931 total responses.
#      response_id persona_id    community occupation  \
# 0           R001       P001  Community 1    Teacher
# 1           R002       P001  Community 1    Teacher
# 2           R003       P001  Community 1    Teacher
# 3           R004       P001  Community 1    Teacher
# 4           R005       P001  Community 1    Teacher
# ...          ...        ...          ...        ...
# 1926       R1927       P200  Community 2    Teacher
# 1927       R1928       P200  Community 2    Teacher
# 1928       R1929       P200  Community 2    Teacher
# 1929       R1930       P200  Community 2    Teacher
# 1930       R1931       P200  Community 2    Teacher
#
#                               priority_choice
# 0     Repair Power Residential in Community 1
# 1          Repair Water School in Community 1
# 2          Repair Water School in Community 3
# 3     Repair Water Residential in Community 1
# 4     Repair Water Residential in Community 2
# ...                                       ...
# 1926   Repair Water Commercial in Community 2
# 1927       Repair Water School in Community 1
# 1928  Repair Water Residential in Community 2
# 1929   Repair Water Commercial in Community 2
# 1930  Repair Power Residential in Community 1
#
# [1931 rows x 5 columns]

# %% [markdown]
# ##Run this!!

# %%
import pandas as pd
import ast

# Read the CSV file
df = pd.read_csv('personas_and_responses.csv')

# Print column names
print(df.columns)

# Function to extract community details
def extract_community_details(description):
    details = {}
    parts = description.split(';')
    for part in parts:
        if 'Working infrastructure:' in part:
            details['working_infrastructure'] = part.split(':')[1].strip()
        elif 'Damaged infrastructure:' in part:
            details['damaged_infrastructure'] = part.split(':')[1].strip()
        elif 'Population:' in part:
            details['population'] = part.split(':')[1].strip()
        elif 'Social vulnerability score:' in part:
            details['social_vulnerability_score'] = part.split(':')[1].strip()
        elif 'Access to resources:' in part:
            details['access_to_resources'] = part.split(':')[1].strip()
    if 'Additional trait:' in description:
        details['additional_trait'] = description.split('Additional trait:')[1].strip()
    return details

# Process the dataframe
def process_dataframe(df):
    # Generate response_id
    df['response_id'] = ['R' + str(i+1).zfill(3) for i in range(len(df))]

    # Add scenario_id (assuming it's constant for all rows)
    df['scenario_id'] = 'S001'

    # Extract community details
    community_details = df['community_description'].apply(extract_community_details)

    # Update dataframe with extracted details
    df['working_infrastructure'] = community_details.apply(lambda x: x.get('working_infrastructure', ''))
    df['damaged_infrastructure'] = community_details.apply(lambda x: x.get('damaged_infrastructure', ''))
    df['population'] = community_details.apply(lambda x: x.get('population', ''))
    df['social_vulnerability_score'] = community_details.apply(lambda x: x.get('social_vulnerability_score', ''))
    df['access_to_resources'] = community_details.apply(lambda x: x.get('access_to_resources', ''))
    df['additional_trait'] = community_details.apply(lambda x: x.get('additional_trait', ''))

    # Ensure 'ordered_pair' is a string representation of a list
    df['ordered_pair'] = df['ordered_pair'].apply(lambda x: str(x) if isinstance(x, list) else x)

    # Reorder columns
    column_order = [
    'persona_id', 'community', 'age', 'occupation', 'household_composition',
    'disaster_experience', 'socioeconomic_status', 'community_description',
    'question_id', 'option1', 'option2', 'response_id', 'priority_choice', 'ordered_pair', 'reasoning'
]

    return df[column_order]

# Process the dataframe
df_processed = process_dataframe(df)

# Save the processed dataframe to a new CSV file
df_processed.to_csv('processed_data.csv', index=False)

print("Data has been processed and saved to 'processed_data.csv'")
# Out:
# Index(['response_id', 'scenario_id', 'persona_id', 'question_id', 'option1',
#        'option2', 'priority_choice', 'reasoning', 'ordered_pair', 'community',
#        'age', 'occupation', 'household_composition', 'disaster_experience',
#        'socioeconomic_status', 'community_description'],
#       dtype='object')
# Data has been processed and saved to 'processed_data.csv'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Making data fit for model

# %%
import pandas as pd
import ast

# Read the CSV file
df = pd.read_csv('personas_and_responses.csv')

# Function to extract community details
def extract_community_details(description):
    details = {}
    parts = description.split(';')
    for part in parts:
        if 'Population:' in part:
            details['population'] = part.split(':')[1].strip()
        elif 'Social vulnerability score:' in part:
            details['social_vulnerability_score'] = part.split(':')[1].strip()
        elif 'Access to resources:' in part:
            details['access_to_resources'] = part.split(':')[1].strip()
    return details

# Process the dataframe
def process_dataframe(df):
    # Extract community details
    community_details = df['community_description'].apply(extract_community_details)

    # Update dataframe with extracted details
    df['population'] = community_details.apply(lambda x: x.get('population', ''))
    df['social_vulnerability_score'] = community_details.apply(lambda x: x.get('social_vulnerability_score', ''))
    df['access_to_resources'] = community_details.apply(lambda x: x.get('access_to_resources', ''))

    # Convert population to numeric
    df['population'] = pd.to_numeric(df['population'], errors='coerce')

    # Convert social vulnerability score to numeric (assuming it's in format "X/10")
    df['social_vulnerability_score'] = df['social_vulnerability_score'].apply(lambda x: float(x.split('/')[0]) / 10)

    # Encode access to resources
    resource_mapping = {'Limited': 0, 'Moderate': 1, 'Good': 2}
    df['access_to_resources'] = df['access_to_resources'].map(resource_mapping)

    # Ensure 'ordered_pair' is a list
    df['ordered_pair'] = df['ordered_pair'].apply(ast.literal_eval)

    # Create separate columns for option1 and option2
    df['option1'] = df['ordered_pair'].apply(lambda x: x[0])
    df['option2'] = df['ordered_pair'].apply(lambda x: x[1])

    # Reorder columns
    column_order = [
        'persona_id', 'community', 'population', 'social_vulnerability_score', 'access_to_resources',
        'question_id', 'option1', 'option2', 'priority_choice', 'ordered_pair',
    ]

    return df[column_order]

# Process the dataframe
df_processed = process_dataframe(df)

# Save the processed dataframe to a new CSV file
df_processed.to_csv('community_focused_data.csv', index=False)

print("Data has been processed and saved to 'community_focused_data.csv'")
# Out:
# Data has been processed and saved to 'community_focused_data.csv'

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('community_focused_data.csv')

# Save as Excel file
df.to_excel('output_communities.xlsx', index=False)

print("Data has been converted to Excel format: output_communities.xlsx")
# Out:
# Data has been converted to Excel format: output_communities.xlsx

# %% [markdown]
# ##Processed pairwise data

# %%
import pandas as pd
import ast

# Define column names
columns = ['persona_id', 'community', 'population', 'social_vulnerability_score', 'access_to_resources',
           'question_id', 'option1', 'option2', 'priority_choice', 'ordered_pair']

# Read the CSV file, specifying the column names and that the file uses comma as separator
df = pd.read_csv('community_focused_data.csv', names=columns, skiprows=1)

# Function to create pairwise comparisons
def create_pairwise_data(row):
    options = ast.literal_eval(row['ordered_pair'])
    return pd.DataFrame({
        'persona_id': [row['persona_id'], row['persona_id']],
        'community': [row['community'], row['community']],
        'population': [row['population'], row['population']],
        'social_vulnerability_score': [row['social_vulnerability_score'], row['social_vulnerability_score']],
        'access_to_resources': [row['access_to_resources'], row['access_to_resources']],
        'option': options,
        'label': [1, 0]  # 1 for chosen option (first in ordered pair), 0 for not chosen
    })

# Create pairwise dataset
pairwise_df = pd.concat(df.apply(create_pairwise_data, axis=1).tolist(), ignore_index=True)

# Extract the community number from the option
pairwise_df['target_community'] = pairwise_df['option'].str.extract(r'Community (\d+)')

# Normalize numerical features
pairwise_df['population'] = (pairwise_df['population'] - pairwise_df['population'].min()) / (pairwise_df['population'].max() - pairwise_df['population'].min())
pairwise_df['social_vulnerability_score'] = pd.to_numeric(pairwise_df['social_vulnerability_score'])

# Create feature vectors
feature_columns = ['population', 'social_vulnerability_score', 'access_to_resources', 'target_community']

# Save the processed dataframe
pairwise_df.to_csv('processed_pairwise_data.csv', index=False)

print("Data has been processed and saved to 'processed_pairwise_data.csv'")
# Out:
# Data has been processed and saved to 'processed_pairwise_data.csv'

# %%
import pandas as pd
import ast

# Define column names
columns = ['persona_id', 'community', 'population', 'social_vulnerability_score', 'access_to_resources',
           'question_id', 'option1', 'option2', 'priority_choice', 'ordered_pair']

# Read the CSV file, specifying the column names and that the file uses comma as separator
df = pd.read_csv('community_focused_data.csv', names=columns, skiprows=1)

# Function to create pairwise comparisons
def create_pairwise_data(row):
    options = ast.literal_eval(row['ordered_pair'])
    return pd.DataFrame({
        'persona_id': row['persona_id'],
        'community': row['community'],
        'population': row['population'],
        'social_vulnerability_score': row['social_vulnerability_score'],
        'access_to_resources': row['access_to_resources'],
        'question_id': row['question_id'],
        'option_a': options[0],
        'option_b': options[1],
        'chosen': 1 if row['priority_choice'] == options[0] else -1
    }, index=[0])

# Create pairwise dataset
pairwise_df = pd.concat(df.apply(create_pairwise_data, axis=1).tolist(), ignore_index=True)

# Extract features from options
pairwise_df['infrastructure_a'] = pairwise_df['option_a'].str.split().str[1]
pairwise_df['community_a'] = pairwise_df['option_a'].str.extract(r'Community (\d+)').astype(int)
pairwise_df['infrastructure_b'] = pairwise_df['option_b'].str.split().str[1]
pairwise_df['community_b'] = pairwise_df['option_b'].str.extract(r'Community (\d+)').astype(int)

# Save the processed dataframe
pairwise_df.to_csv('processed_pairwise_data.csv', index=False)

print("Data has been processed and saved to 'processed_pairwise_data.csv'")
# Out:
# Data has been processed and saved to 'processed_pairwise_data.csv'
